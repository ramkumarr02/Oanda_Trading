# %% [markdown]
# # Oanda Demo Trading Notebook

# %% [markdown]
# #### Packages

# %% [markdown]
# Normal Packages

# %%
import numpy as np
import pandas as pd

import yaml
import json

import time
import winsound

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Oanda Packages

# %%
from oandapyV20 import API
import oandapyV20.endpoints.trades as trades
import oandapyV20.endpoints.pricing as pricing
import oandapyV20.endpoints.accounts as accounts

import oandapyV20.definitions.pricing as defpricing
import oandapyV20.endpoints.instruments as instruments

# %% [markdown]
# #### API Setup

# %% [markdown]
# Read from config file

# %%
config_file = 'config/access_token.yaml'

with open(config_file) as c_file:
    config = yaml.load(c_file)

access_token = config['oanda_demo_account']['token']
accountID = config['oanda_demo_account']['account_id']

api = API(access_token = access_token)

# %% [markdown]
# #### Retrive Data

# %% [markdown]
# Get Trade list

# %%
trade_info = trades.TradesList(accountID)
api.request(trade_info)
print(trade_info.response)
# Out:
# {'trades': [], 'lastTransactionID': '23'}

# %% [markdown]
# Get Account Details

# %%
acct_info = accounts.AccountDetails(accountID = accountID)
api.request(acct_info)

acct_info.response
# Out:
# {'account': {'guaranteedStopLossOrderMode': 'ALLOWED',
#   'hedgingEnabled': False,
#   'id': '101-003-15069707-001',
#   'createdTime': '2020-06-02T05:27:47.736583433Z',
#   'currency': 'SGD',
#   'createdByUserID': 15069707,
#   'alias': 'Primary',
#   'marginRate': '0.05',
#   'lastTransactionID': '23',
#   'balance': '100000.0007',
#   'openTradeCount': 0,
#   'openPositionCount': 0,
#   'pendingOrderCount': 0,
#   'pl': '0.0007',
#   'resettablePL': '0.0007',
#   'resettablePLTime': '0',
#   'financing': '0.0000',
#   'commission': '0.0000',
#   'dividendAdjustment': '0',
#   'guaranteedExecutionFees': '0.0000',
#   'orders': [],
#   'positions': [{'instrument': 'EUR_USD',
#     'long': {'units': '0',
#      'pl': '0.0007',
#      'resettablePL': '0.0007',
#      'financing': '0.0000',
#      'dividendAdjustment': '0.0000',
#      'guaranteedExecutionFees': '0.0000',
#      'unrealizedPL': '0.0000'},
#     'short': {'units': '0',
#      'pl': '0.0000',
#      'resettablePL': '0.0000',
#      'financing': '0.0000',
#      'dividendAdjustment': '0.0000',
#      'guaranteedExecutionFees': '0.0000',
#      'unrealizedPL': '0.0000'},
#     'pl': '0.0007',
#     'resettablePL': '0.0007',
#     'financing': '0.0000',
#     'commission': '0.0000',
#     'dividendAdjustment': '0.0000',
#     'guaranteedExecutionFees': '0.0000',
#     'unrealizedPL': '0.0000',
#     'marginUsed': '0.0000'}],
#   'trades': [],
#   'unrealizedPL': '0.0000',
#   'NAV': '100000.0007',
#   'marginUsed': '0.0000',
#   'marginAvailable': '100000.0007',
#   'positionValue': '0.0000',
#   'marginCloseoutUnrealizedPL': '0.0000',
#   'marginCloseoutNAV': '100000.0007',
#   'marginCloseoutMarginUsed': '0.0000',
#   'marginCloseoutPositionValue': '0.0000',
#   'marginCloseoutPercent': '0.00000',
#   'withdrawalLimit': '100000.0007',
#   'marginCallMarginUsed': '0.0000',
#   'marginCallPercent': '0.00000'},
#  'lastTransactionID': '23'}

# %%
acct_info.response['account']['positions'][0]['long']
# Out:
# {'units': '0',
#  'pl': '0.0007',
#  'resettablePL': '0.0007',
#  'financing': '0.0000',
#  'dividendAdjustment': '0.0000',
#  'guaranteedExecutionFees': '0.0000',
#  'unrealizedPL': '0.0000'}

# %% [markdown]
# Get candle data

# %%
params = {
  "count": 10,
  "granularity": "M1",
  "from": "2020-05-06"
  }
r = instruments.InstrumentsCandles(instrument="EUR_USD", params=params)
api.request(r)
df = pd.DataFrame(r.response['candles'])
df1 = df['mid']
df1
# Out:
# 0    {'o': '1.08349', 'h': '1.08354', 'l': '1.08349...
# 1    {'o': '1.08350', 'h': '1.08352', 'l': '1.08350...
# 2    {'o': '1.08350', 'h': '1.08354', 'l': '1.08348...
# 3    {'o': '1.08350', 'h': '1.08359', 'l': '1.08350...
# 4    {'o': '1.08356', 'h': '1.08359', 'l': '1.08353...
# 5    {'o': '1.08356', 'h': '1.08356', 'l': '1.08348...
# 6    {'o': '1.08356', 'h': '1.08356', 'l': '1.08348...
# 7    {'o': '1.08347', 'h': '1.08348', 'l': '1.08347...
# 8    {'o': '1.08346', 'h': '1.08348', 'l': '1.08337...
# 9    {'o': '1.08344', 'h': '1.08348', 'l': '1.08342...
# Name: mid, dtype: object

# %% [markdown]
# Get Price details

# %%
params = {
    'instruments': 'EUR_USD'
}

price_info = pricing.PricingInfo(accountID = accountID, params = params)
price = api.request(price_info)

#print(price)
print(json.dumps(price, indent = 2))
# Out:
# {
#   "time": "2020-06-05T10:07:26.642897962Z",
#   "prices": [
#     {
#       "type": "PRICE",
#       "time": "2020-06-05T10:07:25.457612070Z",
#       "bids": [
#         {
#           "price": "1.13239",
#           "liquidity": 1000000
#         },
#         {
#           "price": "1.13238",
#           "liquidity": 2000000
#         },
#         {
#           "price": "1.13237",
#           "liquidity": 2000000
#         },
#         {
#           "price": "1.13235",
#           "liquidity": 5000000
#         }
#       ],
#       "asks": [
#         {
#           "price": "1.13247",
#           "liquidity": 1000000
#         },
#         {
#           "price": "1.13249",
#           "liquidity": 2000000
#         },
#         {
#           "price": "1.13250",
#           "liquidity": 2000000
#         },
#         {
#           "price": "1.13251",
#           "liquidity": 5000000
#         }
#       ],
#       "closeoutBid": "1.13235",
#       "closeoutAsk": "1.13251",
#       "status": "tradeable",
#       "tradeable": true,
#       "unitsAvailable": {
#         "default": {
#           "long": "1267330",
#           "short": "1267330"
#         },
#         "openOnly": {
#           "long": "1267330",
#           "short": "1267330"
#         },
#         "reduceFirst": {
#           "long": "1267330",
#           "short": "1267330"
#         },
#         "reduceOnly": {
#           "long": "0",
#           "short": "0"
#         }
#       },
#       "quoteHomeConversionFactors": {
#         "positiveUnits": "1.39349000",
#         "negativeUnits": "1.39366000"
#       },
#       "instrument": "EUR_USD"
#     }
#   ]
# }

# %%
price['prices'][0].keys()
# Out:
# dict_keys(['type', 'time', 'bids', 'asks', 'closeoutBid', 'closeoutAsk', 'status', 'tradeable', 'unitsAvailable', 'quoteHomeConversionFactors', 'instrument'])

# %%
price['prices'][0]
# Out:
# {'type': 'PRICE',
#  'time': '2020-06-05T10:07:25.457612070Z',
#  'bids': [{'price': '1.13239', 'liquidity': 1000000},
#   {'price': '1.13238', 'liquidity': 2000000},
#   {'price': '1.13237', 'liquidity': 2000000},
#   {'price': '1.13235', 'liquidity': 5000000}],
#  'asks': [{'price': '1.13247', 'liquidity': 1000000},
#   {'price': '1.13249', 'liquidity': 2000000},
#   {'price': '1.13250', 'liquidity': 2000000},
#   {'price': '1.13251', 'liquidity': 5000000}],
#  'closeoutBid': '1.13235',
#  'closeoutAsk': '1.13251',
#  'status': 'tradeable',
#  'tradeable': True,
#  'unitsAvailable': {'default': {'long': '1267330', 'short': '1267330'},
#   'openOnly': {'long': '1267330', 'short': '1267330'},
#   'reduceFirst': {'long': '1267330', 'short': '1267330'},
#   'reduceOnly': {'long': '0', 'short': '0'}},
#  'quoteHomeConversionFactors': {'positiveUnits': '1.39349000',
#   'negativeUnits': '1.39366000'},
#  'instrument': 'EUR_USD'}

# %%
r = pricing.PricingStream(accountID=accountID, params=params)
rv = api.request(r)

num = 5
n = 0
for resp in rv:
    print(n)

    if n < num:        
        resp_type = resp['type']        

        if resp_type == 'PRICE':
            time_stamp = resp['time']
            date_val, full_time = time_stamp.split(sep = 'T')
            time_val, time_fraction = full_time.split(sep = '.')

            print('date : ',date_val)
            print('time : ',time_val)
            print('time fraction : ',time_fraction)

            bid_price = resp['bids'][0]['price']
            print('bid_price : ',bid_price)

            ask_price = resp['asks'][0]['price']
            print('ask_price : ',ask_price)
            print('\n-----------------------------------------------------------------------')

            n += 1
            #time.sleep(1)
        else:
            print('HEARTBEAT')

    else:
        try:
            r.terminate(message = "maxrecs records received")
        except:
            pass
        
print('hi')
# Out:
# 0
# date :  2020-06-05
# time :  10:09:44
# time fraction :  545726960Z
# bid_price :  1.13192
# ask_price :  1.13199
#
# -----------------------------------------------------------------------
# 1
# date :  2020-06-05
# time :  10:09:44
# time fraction :  816001807Z
# bid_price :  1.13192
# ask_price :  1.13199
#
# -----------------------------------------------------------------------
# 2
# date :  2020-06-05
# time :  10:09:45
# time fraction :  060524282Z
# bid_price :  1.13189
# ask_price :  1.13197
#
# -----------------------------------------------------------------------
# 3
# date :  2020-06-05
# time :  10:09:45
# time fraction :  120455392Z
# bid_price :  1.13188
# ask_price :  1.13196
#
# -----------------------------------------------------------------------
# 4
# date :  2020-06-05
# time :  10:09:47
# time fraction :  028577777Z
# bid_price :  1.13188
# ask_price :  1.13196
#
# -----------------------------------------------------------------------
# 5
# date :  2020-06-05
# time :  10:09:48
# time fraction :  045127094Z
# bid_price :  1.13184
# ask_price :  1.13193
#
# -----------------------------------------------------------------------
# 6
# date :  2020-06-05
# time :  10:09:48
# time fraction :  191061490Z
# bid_price :  1.13183
# ask_price :  1.13191
#
# -----------------------------------------------------------------------
# 7
# date :  2020-06-05
# time :  10:09:49
# time fraction :  114807417Z
# bid_price :  1.13185
# ask_price :  1.13191
#
# -----------------------------------------------------------------------
# 8
# HEARTBEAT
# 8
# date :  2020-06-05
# time :  10:09:52
# time fraction :  238670056Z
# bid_price :  1.13181
# ask_price :  1.13189
#
# -----------------------------------------------------------------------
# 9
# date :  2020-06-05
# time :  10:09:52
# time fraction :  706221546Z
# bid_price :  1.13179
# ask_price :  1.13187
#
# -----------------------------------------------------------------------
# 10
# date :  2020-06-05
# time :  10:09:53
# time fraction :  948509762Z
# bid_price :  1.13178
# ask_price :  1.13186
#
# -----------------------------------------------------------------------
# 11
# HEARTBEAT
# 11
# date :  2020-06-05
# time :  10:09:55
# time fraction :  306929688Z
# bid_price :  1.13175
# ask_price :  1.13183
#
# -----------------------------------------------------------------------
# 12
# date :  2020-06-05
# time :  10:09:56
# time fraction :  389748694Z
# bid_price :  1.13173
# ask_price :  1.13182
#
# -----------------------------------------------------------------------
# 13
# date :  2020-06-05
# time :  10:09:56
# time fraction :  771868266Z
# bid_price :  1.13172
# ask_price :  1.13180
#
# -----------------------------------------------------------------------
# 14
# date :  2020-06-05
# time :  10:09:57
# time fraction :  038568539Z
# bid_price :  1.13170
# ask_price :  1.13178
#
# -----------------------------------------------------------------------
# 15
# date :  2020-06-05
# time :  10:09:58
# time fraction :  083567630Z
# bid_price :  1.13171
# ask_price :  1.13179
#
# -----------------------------------------------------------------------
# 16
# date :  2020-06-05
# time :  10:09:58
# time fraction :  548795379Z
# bid_price :  1.13174
# ask_price :  1.13182
#
# -----------------------------------------------------------------------
# 17
# date :  2020-06-05
# time :  10:09:59
# time fraction :  089220798Z
# bid_price :  1.13172
# ask_price :  1.13181
#
# -----------------------------------------------------------------------
# 18
# date :  2020-06-05
# time :  10:10:00
# time fraction :  077633474Z
# bid_price :  1.13175
# ask_price :  1.13183
#
# -----------------------------------------------------------------------
# 19
# HEARTBEAT
# 19
# date :  2020-06-05
# time :  10:10:00
# time fraction :  293735212Z
# bid_price :  1.13179
# ask_price :  1.13188
#
# -----------------------------------------------------------------------
# 20
# date :  2020-06-05
# time :  10:10:03
# time fraction :  053507162Z
# bid_price :  1.13179
# ask_price :  1.13186
#
# -----------------------------------------------------------------------
# 21
# date :  2020-06-05
# time :  10:10:03
# time fraction :  405550340Z
# bid_price :  1.13178
# ask_price :  1.13185
#
# -----------------------------------------------------------------------
# 22
# date :  2020-06-05
# time :  10:10:03
# time fraction :  674555228Z
# bid_price :  1.13180
# ask_price :  1.13187
#
# -----------------------------------------------------------------------
# 23
# date :  2020-06-05
# time :  10:10:03
# time fraction :  881997699Z
# bid_price :  1.13181
# ask_price :  1.13188
#
# -----------------------------------------------------------------------
# 24
# date :  2020-06-05
# time :  10:10:04
# time fraction :  329729351Z
# bid_price :  1.13180
# ask_price :  1.13189
#
# -----------------------------------------------------------------------
# 25
# date :  2020-06-05
# time :  10:10:04
# time fraction :  571144732Z
# bid_price :  1.13179
# ask_price :  1.13187
#
# -----------------------------------------------------------------------
# 26
# HEARTBEAT
# 26
# date :  2020-06-05
# time :  10:10:06
# time fraction :  564533381Z
# bid_price :  1.13180
# ask_price :  1.13188
#
# -----------------------------------------------------------------------
# 27
# date :  2020-06-05
# time :  10:10:06
# time fraction :  737089928Z
# bid_price :  1.13182
# ask_price :  1.13190
#
# -----------------------------------------------------------------------
# 28
# date :  2020-06-05
# time :  10:10:06
# time fraction :  914284138Z
# bid_price :  1.13181
# ask_price :  1.13189
#
# -----------------------------------------------------------------------
# 29
# date :  2020-06-05
# time :  10:10:07
# time fraction :  294894578Z
# bid_price :  1.13181
# ask_price :  1.13189
#
# -----------------------------------------------------------------------
# 30
# date :  2020-06-05
# time :  10:10:08
# time fraction :  058850967Z
# bid_price :  1.13182
# ask_price :  1.13190
#
# -----------------------------------------------------------------------
# 31
# date :  2020-06-05
# time :  10:10:08
# time fraction :  229458262Z
# bid_price :  1.13184
# ask_price :  1.13192
#
# -----------------------------------------------------------------------
# 32
# date :  2020-06-05
# time :  10:10:08
# time fraction :  514183016Z
# bid_price :  1.13180
# ask_price :  1.13188
#
# -----------------------------------------------------------------------
# 33
# date :  2020-06-05
# time :  10:10:08
# time fraction :  618806823Z
# bid_price :  1.13181
# ask_price :  1.13189
#
# -----------------------------------------------------------------------
# 34
# date :  2020-06-05
# time :  10:10:09
# time fraction :  582917241Z
# bid_price :  1.13184
# ask_price :  1.13192
#
# -----------------------------------------------------------------------
# 35
# HEARTBEAT
# 35
# date :  2020-06-05
# time :  10:10:11
# time fraction :  511679699Z
# bid_price :  1.13183
# ask_price :  1.13191
#
# -----------------------------------------------------------------------
# 36
# date :  2020-06-05
# time :  10:10:11
# time fraction :  700232372Z
# bid_price :  1.13184
# ask_price :  1.13192
#
# -----------------------------------------------------------------------
# 37
# date :  2020-06-05
# time :  10:10:13
# time fraction :  372240847Z
# bid_price :  1.13183
# ask_price :  1.13191
#
# -----------------------------------------------------------------------
# 38
# date :  2020-06-05
# time :  10:10:14
# time fraction :  609175503Z
# bid_price :  1.13188
# ask_price :  1.13196
#
# -----------------------------------------------------------------------
# 39
# date :  2020-06-05
# time :  10:10:14
# time fraction :  802655452Z
# bid_price :  1.13189
# ask_price :  1.13197
#
# -----------------------------------------------------------------------
# 40
# HEARTBEAT
# 40
# date :  2020-06-05
# time :  10:10:16
# time fraction :  356910774Z
# bid_price :  1.13191
# ask_price :  1.13199
#
# -----------------------------------------------------------------------
# 41
# date :  2020-06-05
# time :  10:10:16
# time fraction :  429406932Z
# bid_price :  1.13192
# ask_price :  1.13200
#
# -----------------------------------------------------------------------
# 42
# date :  2020-06-05
# time :  10:10:17
# time fraction :  358383757Z
# bid_price :  1.13196
# ask_price :  1.13204
#
# -----------------------------------------------------------------------
# 43
# date :  2020-06-05
# time :  10:10:17
# time fraction :  516099508Z
# bid_price :  1.13195
# ask_price :  1.13204
#
# -----------------------------------------------------------------------
# 44
# date :  2020-06-05
# time :  10:10:17
# time fraction :  665313643Z
# bid_price :  1.13195
# ask_price :  1.13203
#
# -----------------------------------------------------------------------
# 45
# date :  2020-06-05
# time :  10:10:18
# time fraction :  033966972Z
# bid_price :  1.13194
# ask_price :  1.13202
#
# -----------------------------------------------------------------------
# 46
# date :  2020-06-05
# time :  10:10:19
# time fraction :  374737797Z
# bid_price :  1.13196
# ask_price :  1.13204
#
# -----------------------------------------------------------------------
# 47
# date :  2020-06-05
# time :  10:10:19
# time fraction :  571906379Z
# bid_price :  1.13196
# ask_price :  1.13204
#
# -----------------------------------------------------------------------
# 48
# date :  2020-06-05
# time :  10:10:20
# time fraction :  356214349Z
# bid_price :  1.13198
# ask_price :  1.13206
#
# -----------------------------------------------------------------------
# 49
# HEARTBEAT
# 49
# date :  2020-06-05
# time :  10:10:20
# time fraction :  630577030Z
# bid_price :  1.13199
# ask_price :  1.13207
#
# -----------------------------------------------------------------------
# 50
# hi

# %%
winsound.PlaySound('C:\\Windows\\Media\\tada.wav', winsound.SND_ASYNC)
