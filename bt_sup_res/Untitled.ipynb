# %%
from numba import jit, cuda

# %%
from timeit import default_timer as timer

# %%
from numba import vectorize, jit, cuda 
import numpy as np 
from timeit import default_timer as timer 


def func(a):                                 
    for i in range(10000000): 
        a[i]+= 1    

@vectorize(['float64(float64)'], target ="cuda")                         
def func2(x): 
    return x+1

if __name__=="__main__": 
    n = 10000000                            
    a = np.ones(n, dtype = np.float64) 

    start = timer() 
    func(a) 
    print("without GPU:", timer()-start)     

    start = timer() 
    func2(a) 
    print("with GPU:", timer()-start)
# Out:
# without GPU: 4.0131772
# with GPU: 0.7137416999999999

# %%
# %%time
for i in np.arange(1,1000000):
    i = i + 1
# Out:
# Wall time: 3.36 s

# %%
@vectorize(['float64(float64)'], target ="cuda")   
def test_run(x):
    for i in np.arange(1,x):
        i = i + 1   
    return()
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-20-32716fa1a995> in <module>
# ----> 1 @vectorize(['float64(float64)'], target ="cuda")
#       2 def test_run(x):
#       3     for i in np.arange(1,x):
#       4         i = i + 1
#       5     return()
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\np\ufunc\decorators.py in wrap(func)
#     118         vec = Vectorize(func, **kws)
#     119         for sig in ftylist:
# --> 120             vec.add(sig)
#     121         if len(ftylist) > 0:
#     122             vec.disable_compile()
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\np\ufunc\deviceufunc.py in add(***failed resolving arguments***)
#     397         kernelsource = self._get_kernel_source(self._kernel_template,
#     398                                                devfnsig, funcname)
# --> 399         corefn, return_type = self._compile_core(devfnsig)
#     400         glbl = self._get_globals(corefn)
#     401         sig = signature(types.void, *([a[:] for a in args] + [return_type[:]]))
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\cuda\vectorizers.py in _compile_core(self, sig)
#      13 class CUDAVectorize(deviceufunc.DeviceVectorize):
#      14     def _compile_core(self, sig):
# ---> 15         cudevfn = cuda.jit(sig, device=True, inline=True)(self.pyfunc)
#      16         return cudevfn, cudevfn.cres.signature.return_type
#      17
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\cuda\decorators.py in device_jit(func)
#     138         def device_jit(func):
#     139             return compile_device(func, restype, argtypes, inline=inline,
# --> 140                                   debug=debug)
#     141
#     142         if device:
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\cuda\compiler.py in compile_device(pyfunc, return_type, args, inline, debug)
#     290
#     291 def compile_device(pyfunc, return_type, args, inline=True, debug=False):
# --> 292     return DeviceFunction(pyfunc, return_type, args, inline=True, debug=False)
#     293
#     294
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\cuda\compiler.py in __init__(self, pyfunc, return_type, args, inline, debug)
#     321         self.debug = False
#     322         cres = compile_cuda(self.py_func, self.return_type, self.args,
# --> 323                             debug=self.debug, inline=self.inline)
#     324         self.cres = cres
#     325
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\cuda\compiler.py in compile_cuda(pyfunc, return_type, args, debug, inline)
#      44                                   return_type=return_type,
#      45                                   flags=flags,
# ---> 46                                   locals={})
#      47
#      48     library = cres.library
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     600     pipeline = pipeline_class(typingctx, targetctx, library,
#     601                               args, return_type, flags, locals)
# --> 602     return pipeline.compile_extra(func)
#     603
#     604
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler.py in compile_extra(self, func)
#     350         self.state.lifted = ()
#     351         self.state.lifted_from = None
# --> 352         return self._compile_bytecode()
#     353
#     354     def compile_ir(self, func_ir, lifted=(), lifted_from=None):
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler.py in _compile_bytecode(self)
#     412         """
#     413         assert self.state.func_ir is None
# --> 414         return self._compile_core()
#     415
#     416     def _compile_ir(self):
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler.py in _compile_core(self)
#     392                 self.state.status.fail_reason = e
#     393                 if is_final_pipeline:
# --> 394                     raise e
#     395         else:
#     396             raise CompilerError("All available pipelines exhausted")
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler.py in _compile_core(self)
#     383             res = None
#     384             try:
# --> 385                 pm.run(self.state)
#     386                 if self.state.cr is not None:
#     387                     break
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler_machinery.py in run(self, state)
#     337                     (self.pipeline_name, pass_desc)
#     338                 patched_exception = self._patch_error(msg, e)
# --> 339                 raise patched_exception
#     340
#     341     def dependency_analysis(self):
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler_machinery.py in run(self, state)
#     328                 pass_inst = _pass_registry.get(pss).pass_inst
#     329                 if isinstance(pass_inst, CompilerPass):
# --> 330                     self._runPass(idx, pass_inst, state)
#     331                 else:
#     332                     raise BaseException("Legacy pass in use")
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler_machinery.py in _runPass(self, index, pss, internal_state)
#     287             mutated |= check(pss.run_initialization, internal_state)
#     288         with SimpleTimer() as pass_time:
# --> 289             mutated |= check(pss.run_pass, internal_state)
#     290         with SimpleTimer() as finalize_time:
#     291             mutated |= check(pss.run_finalizer, internal_state)
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler_machinery.py in check(func, compiler_state)
#     260
#     261         def check(func, compiler_state):
# --> 262             mangled = func(compiler_state)
#     263             if mangled not in (True, False):
#     264                 msg = ("CompilerPass implementations should return True/False. "
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\typed_passes.py in run_pass(self, state)
#      98                 state.return_type,
#      99                 state.locals,
# --> 100                 raise_errors=self._raise_errors)
#     101             state.typemap = typemap
#     102             if self._raise_errors:
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\typed_passes.py in type_inference_stage(typingctx, interp, args, return_type, locals, raise_errors)
#      70
#      71         infer.build_constraint()
# ---> 72         infer.propagate(raise_errors=raise_errors)
#      73         typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      74
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\typeinfer.py in propagate(self, raise_errors)
#    1069                                   if isinstance(e, ForceLiteralArg)]
#    1070                 if not force_lit_args:
# -> 1071                     raise errors[0]
#    1072                 else:
#    1073                     raise reduce(operator.or_, force_lit_args)
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# No conversion from Tuple() to float64 for '$32.2', defined at None
#
# File "<ipython-input-20-32716fa1a995>", line 5:
# def test_run(x):
#     <source elided>
#         i = i + 1
#     return()
#     ^
#
# During: typing of assignment at <ipython-input-20-32716fa1a995> (5)
#
# File "<ipython-input-20-32716fa1a995>", line 5:
# def test_run(x):
#     <source elided>
#         i = i + 1
#     return()
#     ^

# %%
test_run()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\np\ufunc\decorators.py in wrap(func)
#     118         vec = Vectorize(func, **kws)
#     119         for sig in ftylist:
# --> 120             vec.add(sig)
#     121         if len(ftylist) > 0:
#     122             vec.disable_compile()
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\np\ufunc\deviceufunc.py in add(***failed resolving arguments***)
#     397         kernelsource = self._get_kernel_source(self._kernel_template,
#     398                                                devfnsig, funcname)
# --> 399         corefn, return_type = self._compile_core(devfnsig)
#     400         glbl = self._get_globals(corefn)
#     401         sig = signature(types.void, *([a[:] for a in args] + [return_type[:]]))
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\cuda\vectorizers.py in _compile_core(self, sig)
#      13 class CUDAVectorize(deviceufunc.DeviceVectorize):
#      14     def _compile_core(self, sig):
# ---> 15         cudevfn = cuda.jit(sig, device=True, inline=True)(self.pyfunc)
#      16         return cudevfn, cudevfn.cres.signature.return_type
#      17
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\cuda\decorators.py in device_jit(func)
#     138         def device_jit(func):
#     139             return compile_device(func, restype, argtypes, inline=inline,
# --> 140                                   debug=debug)
#     141
#     142         if device:
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\cuda\compiler.py in compile_device(pyfunc, return_type, args, inline, debug)
#     290
#     291 def compile_device(pyfunc, return_type, args, inline=True, debug=False):
# --> 292     return DeviceFunction(pyfunc, return_type, args, inline=True, debug=False)
#     293
#     294
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\cuda\compiler.py in __init__(self, pyfunc, return_type, args, inline, debug)
#     321         self.debug = False
#     322         cres = compile_cuda(self.py_func, self.return_type, self.args,
# --> 323                             debug=self.debug, inline=self.inline)
#     324         self.cres = cres
#     325
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\cuda\compiler.py in compile_cuda(pyfunc, return_type, args, debug, inline)
#      44                                   return_type=return_type,
#      45                                   flags=flags,
# ---> 46                                   locals={})
#      47
#      48     library = cres.library
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     600     pipeline = pipeline_class(typingctx, targetctx, library,
#     601                               args, return_type, flags, locals)
# --> 602     return pipeline.compile_extra(func)
#     603
#     604
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler.py in compile_extra(self, func)
#     350         self.state.lifted = ()
#     351         self.state.lifted_from = None
# --> 352         return self._compile_bytecode()
#     353
#     354     def compile_ir(self, func_ir, lifted=(), lifted_from=None):
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler.py in _compile_bytecode(self)
#     412         """
#     413         assert self.state.func_ir is None
# --> 414         return self._compile_core()
#     415
#     416     def _compile_ir(self):
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler.py in _compile_core(self)
#     392                 self.state.status.fail_reason = e
#     393                 if is_final_pipeline:
# --> 394                     raise e
#     395         else:
#     396             raise CompilerError("All available pipelines exhausted")
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler.py in _compile_core(self)
#     383             res = None
#     384             try:
# --> 385                 pm.run(self.state)
#     386                 if self.state.cr is not None:
#     387                     break
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler_machinery.py in run(self, state)
#     337                     (self.pipeline_name, pass_desc)
#     338                 patched_exception = self._patch_error(msg, e)
# --> 339                 raise patched_exception
#     340
#     341     def dependency_analysis(self):
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler_machinery.py in run(self, state)
#     328                 pass_inst = _pass_registry.get(pss).pass_inst
#     329                 if isinstance(pass_inst, CompilerPass):
# --> 330                     self._runPass(idx, pass_inst, state)
#     331                 else:
#     332                     raise BaseException("Legacy pass in use")
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler_machinery.py in _runPass(self, index, pss, internal_state)
#     287             mutated |= check(pss.run_initialization, internal_state)
#     288         with SimpleTimer() as pass_time:
# --> 289             mutated |= check(pss.run_pass, internal_state)
#     290         with SimpleTimer() as finalize_time:
#     291             mutated |= check(pss.run_finalizer, internal_state)
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\compiler_machinery.py in check(func, compiler_state)
#     260
#     261         def check(func, compiler_state):
# --> 262             mangled = func(compiler_state)
#     263             if mangled not in (True, False):
#     264                 msg = ("CompilerPass implementations should return True/False. "
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\numba\core\untyped_passes.py in run_pass(self, state)
#     105             raise TypeError("Signature mismatch: %d argument types given, "
#     106                             "but function takes %d arguments"
# --> 107                             % (len(state['args']), state['nargs']))
#     108         return True
#     109
#
# TypeError: Failed in nopython mode pipeline (step: fix up args)
# Signature mismatch: 1 argument types given, but function takes 0 arguments
