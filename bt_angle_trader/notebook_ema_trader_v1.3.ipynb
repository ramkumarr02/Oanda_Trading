# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *

# %%
data['pl_move_flag'] = True
data['stop_loss_flag'] = False

# %%
# %%time
data = get_date_list(data)
data = read_data(data)
data = run_engine(data)

if data["plot"]:
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['date_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df'].groupby(['date_val'])['close_type'].sum())
print('-----------------------------------------------------')
print(data['report_df']['pls'].value_counts())
print('-----------------------------------------------------')
data['report_df']
# Out:
#  94%|████████████████ | 35562/37727 [00:40<00:02, 812.72it/s]
# pls   -0.0046
# dtype: float64
# --------------------------------------
#                  date     close_type      pls
# 0 2021-04-04 22:27:43  pl_move_close  0.00003
# 1 2021-04-05 08:21:49  reverse_close -0.00087
# 2 2021-04-05 09:08:41  reverse_close  0.00048
# 3 2021-04-05 11:07:24  reverse_close  0.00028
# 4 2021-04-05 14:53:10  reverse_close -0.00535
# 5 2021-04-05 15:28:51  reverse_close  0.00077
# 6 2021-04-05 19:39:51  pl_move_close  0.00006
# 100%|█████████████████| 37727/37727 [00:42<00:00, 879.42it/s]
# -----------------------------------------------------
# ==============================
# date_val          : ['20210404', '20210405']
# Total PL : -0.0046
# -------------
# net_pl            : -0.0046/0.00784
# -------------
# +ve               : num= 5    sum= +0.00162    avg= +0.00032
# -ve               : num= 2    sum= -0.00622    avg= -0.00311
# ==============================
# -----------------------------------------------------
# date_val
# 4    0.00003
# 5   -0.00463
# Name: pls, dtype: float64
# -----------------------------------------------------
# date_val
# 4                                        pl_move_close
# 5    reverse_closereverse_closereverse_closereverse...
# Name: close_type, dtype: object
# -----------------------------------------------------
#  0.00028    1
#  0.00077    1
#  0.00048    1
# -0.00535    1
# -0.00087    1
#  0.00003    1
#  0.00006    1
# Name: pls, dtype: int64
# -----------------------------------------------------
# Wall time: 50.1 s
#                  date  year_val  month_val  date_val  hour_val  minute_val  \
# 0 2021-04-04 22:27:43      2021          4         4        22          27
# 1 2021-04-05 08:21:49      2021          4         5         8          21
# 2 2021-04-05 09:08:41      2021          4         5         9           8
# 3 2021-04-05 11:07:24      2021          4         5        11           7
# 4 2021-04-05 14:53:10      2021          4         5        14          53
# 5 2021-04-05 15:28:51      2021          4         5        15          28
# 6 2021-04-05 19:39:51      2021          4         5        19          39
#
#       close_type      pls
# 0  pl_move_close  0.00003
# 1  reverse_close -0.00087
# 2  reverse_close  0.00048
# 3  reverse_close  0.00028
# 4  reverse_close -0.00535
# 5  reverse_close  0.00077
# 6  pl_move_close  0.00006
