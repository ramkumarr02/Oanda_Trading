# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *

# %%
data['pl_move_flag'] = True
data['stop_loss_flag'] = False

# %%
# %%time
data = get_date_list(data)
data = read_data(data)
data = run_engine(data)

if data["plot"]:
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['date_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df']['pls'].value_counts())
print('-----------------------------------------------------')
data['report_df']
# Out:
#  53%|████████▉        | 19944/37727 [00:22<00:23, 758.45it/s]
# pls    0.00011
# dtype: float64
# --------------------------------------
#                  date     close_type      pls
# 0 2021-04-04 23:10:41  pl_move_close  0.00005
# 1 2021-04-05 12:19:28  pl_move_close  0.00006
# 100%|█████████████████| 37727/37727 [00:43<00:00, 863.37it/s]
# -----------------------------------------------------
# ==============================
# date_val          : ['20210404', '20210405']
# Total PL : 0.00011
# -------------
# net_pl            : 0.00011/0.00011
# -------------
# +ve               : num= 2    sum= +0.00011    avg= +6e-05
# -ve               : num= 0    sum= 0.0    avg= nan
# ==============================
# -----------------------------------------------------
# date_val
# 4    0.00005
# 5    0.00006
# Name: pls, dtype: float64
# -----------------------------------------------------
# 0.00006    1
# 0.00005    1
# Name: pls, dtype: int64
# -----------------------------------------------------
# Wall time: 50.9 s
#                  date  year_val  month_val  date_val  hour_val  minute_val  \
# 0 2021-04-04 23:10:41      2021          4         4        23          10
# 1 2021-04-05 12:19:28      2021          4         5        12          19
#
#       close_type      pls
# 0  pl_move_close  0.00005
# 1  pl_move_close  0.00006
