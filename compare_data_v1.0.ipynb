# %%
import os
import winsound
import numpy as np
import pandas as pd
import datetime as dt
from tqdm import tqdm
tqdm.pandas()
from multiprocessing import  Pool
import time

import math, collections
from scipy.stats import linregress

from matplotlib import pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data\live_preds.csv')
df.head()
# Out:
#   predicted_direction  tick_avg  spread_avg   tick_sd      diff  avg_gain  \
# 0                same  1.228242    0.000080  0.000075  0.000214  0.000037
# 1                same  1.228369    0.000082  0.000044  0.000127  0.000046
# 2                same  1.228499    0.000085  0.000032  0.000130  0.000052
# 3                same  1.228562    0.000075  0.000038  0.000063  0.000052
# 4                same  1.228641    0.000071  0.000016  0.000079  0.000051
#
#    avg_loss        rs        rsi      sema  ...      lema     lema_diff  \
# 0  0.000029  1.271766  55.981385  1.228130  ...  1.228273 -3.499938e-07
# 1  0.000025  1.826305  64.618108  1.228155  ...  1.228278  5.027293e-06
# 2  0.000025  2.097212  67.712901  1.228193  ...  1.228289  1.066024e-05
# 3  0.000025  2.070765  67.434823  1.228232  ...  1.228301  1.285945e-05
# 4  0.000025  2.057184  67.290157  1.228277  ...  1.228317  1.575233e-05
#
#        lsma  lsma_diff  ema_diff  sma_diff  max_tick  min_tick   max_gap  \
# 0  1.228346   0.000003 -0.000143 -0.000195  1.228277  1.228026  0.000035
# 1  1.228350   0.000004 -0.000123 -0.000192  1.228369  1.228026  0.000000
# 2  1.228356   0.000006 -0.000096 -0.000180  1.228499  1.228026  0.000000
# 3  1.228363   0.000007 -0.000069 -0.000173  1.228562  1.228026  0.000000
# 4  1.228371   0.000008 -0.000040 -0.000161  1.228641  1.228026  0.000000
#
#     min_gap
# 0 -0.000215
# 1 -0.000343
# 2 -0.000472
# 3 -0.000535
# 4 -0.000614
#
# [5 rows x 23 columns]
