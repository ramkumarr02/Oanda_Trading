# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *
import winsound

# %%
data["plot"] = True

data['pl_move_trail_trigger']   = 0.0025
data['stop_loss_pip']           = 0.0015

data['input_rows'] = 10000

data['sema_len']        = 30
data['slema_len']       = 75
data['lema_len']        = 300
data['llema_len']       = 750

data['start_date'] = {'year':2021, 'month':1, 'date':4}
data['end_date']   = {'year':2021, 'month':1, 'date':4}

# %% [markdown]
# data['df']['tick'][:3]

# %%
# %%time
data = get_date_list(data)
data = read_data(data)
data = run_engine(data)
# Out:
#  18%|██████▊                              | 818/4449 [00:00<00:00, 7602.81it/s]
# Record num : 4449
# 100%|█████████████████████████████████████| 4449/4449 [00:04<00:00, 944.75it/s]
# Wall time: 4.77 s

# %%
if data["plot"]:
    data = adjust_plot_list_lengths(data)
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['date_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df']['pls'].value_counts())
print('-----------------------------------------------------')
data['report_df']

winsound.PlaySound('C:\\Windows\\Media\\tada.wav', winsound.SND_ASYNC)
# Out:
# -----------------------------------------------------
# ==============================
# date_val          : ['20210104']
# Total PL : 0
# -------------
# net_pl            : 0.0/0.0
# -------------
# +ve               : num= 0    sum= +0.0    avg= +nan
# -ve               : num= 0    sum= 0.0    avg= nan
# ==============================
# -----------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-7761f379ca75> in <module>
#       6 print_report(data)
#       7 print('-----------------------------------------------------')
# ----> 8 print(data['report_df'].groupby(['date_val'])['pls'].sum())
#       9 print('-----------------------------------------------------')
#      10 print(data['report_df']['pls'].value_counts())
#
# KeyError: 'report_df'

# %%
data['report_df'][['date', 'ord_types', 'llema_angle','close_type', 'pls']]
