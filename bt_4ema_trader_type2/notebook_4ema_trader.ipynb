# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *
import winsound

# %%
data["plot"] = True

data['pl_move_trail_trigger']   = 0.0025
data['stop_loss_pip']           = 0.0015

data['input_rows'] = 10000

data['sema_len']        = 30
data['slema_len']       = 75
data['lema_len']        = 300
data['llema_len']       = 750

data['start_date'] = {'year':2021, 'month':1, 'date':4}
data['end_date']   = {'year':2021, 'month':1, 'date':4}

# %%
# %%time
data = get_date_list(data)
data = read_data(data)
data = run_engine(data)
# Out:
# pls   -0.00117
# dtype: float64
# --------------------------------------
#                  date ord_types  llema_angle               close_type      pls
# 0 2021-01-04 00:17:02     short          -11  simple_slema_move_close  0.00007
# 1 2021-01-04 00:22:27     short          -27  simple_slema_move_close  0.00013
# 2 2021-01-04 00:34:54      long           24               sema_close -0.00046
# 3 2021-01-04 00:39:29     short          -20  simple_slema_move_close  0.00012
# 4 2021-01-04 00:49:33     short          -32               sema_close -0.00031
# 5 2021-01-04 00:49:55      long            9               sema_close -0.00013
# 6 2021-01-04 00:50:48     short            0               sema_close -0.00013
# 7 2021-01-04 00:59:19      long           14               sema_close -0.00026
# 8 2021-01-04 01:03:09     short          -14               sema_close -0.00012
# 9 2021-01-04 01:03:19      long            0               sema_close -0.00008
# 100%|█████████████████████████████████████| 4449/4449 [00:22<00:00, 200.02it/s]
# Wall time: 22.3 s

# %%
if data["plot"]:
    data = adjust_plot_list_lengths(data)
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['date_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df']['pls'].value_counts())
print('-----------------------------------------------------')
data['report_df']

winsound.PlaySound('C:\\Windows\\Media\\tada.wav', winsound.SND_ASYNC)
# Out:
# -----------------------------------------------------
# ==============================
# date_val          : ['20210104']
# Total PL : -0.00117
# -------------
# net_pl            : -0.00117/0.00181
# -------------
# +ve               : num= 3    sum= +0.00032    avg= +0.00011
# -ve               : num= 7    sum= -0.00149    avg= -0.00021
# ==============================
# -----------------------------------------------------
# date_val
# 4   -0.00117
# Name: pls, dtype: float64
# -----------------------------------------------------
# -0.00013    2
# -0.00031    1
#  0.00007    1
# -0.00026    1
# -0.00008    1
#  0.00013    1
# -0.00046    1
# -0.00012    1
#  0.00012    1
# Name: pls, dtype: int64
# -----------------------------------------------------

# %%
data['report_df'][['date', 'ord_types', 'llema_angle','close_type', 'pls']]
# Out:
#                  date ord_types  llema_angle               close_type      pls
# 0 2021-01-04 00:17:02     short          -11  simple_slema_move_close  0.00007
# 1 2021-01-04 00:22:27     short          -27  simple_slema_move_close  0.00013
# 2 2021-01-04 00:34:54      long           24               sema_close -0.00046
# 3 2021-01-04 00:39:29     short          -20  simple_slema_move_close  0.00012
# 4 2021-01-04 00:49:33     short          -32               sema_close -0.00031
# 5 2021-01-04 00:49:55      long            9               sema_close -0.00013
# 6 2021-01-04 00:50:48     short            0               sema_close -0.00013
# 7 2021-01-04 00:59:19      long           14               sema_close -0.00026
# 8 2021-01-04 01:03:09     short          -14               sema_close -0.00012
# 9 2021-01-04 01:03:19      long            0               sema_close -0.00008
