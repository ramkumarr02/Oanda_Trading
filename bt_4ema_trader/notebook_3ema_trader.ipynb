# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *
import winsound

# %%
data["plot"] = True

data['direction_flag'] = -1

data['sema_gap_pip'] = 0.0000
data['pl_move_trail_trigger']   = 0.0025
data['stop_loss_pip']           = 0.0015

data['sema_len']        = 20000
data['slema_len']       = 30000
data['lema_len']        = 40000

data['start_date'] = {'year':2021, 'month':1, 'date':1}
data['end_date']   = {'year':2021, 'month':1, 'date':5}

# %%
# %%time
data = get_date_list(data)
data = read_data(data)
data = run_engine(data)
# Out:
#  40%|██████████████▏                    | 85040/210574 [18:33<50:43, 41.25it/s]
# pls   -0.00301
# dtype: float64
# --------------------------------------
#                  date ord_types    close_type      pls
# 0 2021-01-04 15:45:59      long  reverse_stop -0.00151
# 1 2021-01-04 16:05:08     short   simple_stop -0.00150
#  69%|███████████████████████▎          | 144531/210574 [40:33<18:32, 59.39it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# D:\Ram\PCAL\Data_Science\Projects\Trading\Oanda_Trading\bt_3ema_trader\utils\engine.py in run_engine(data)
#      51
#      52         if len(data['lema_list']) == data['lema_len']:
# ---> 53             data = after_lema(data)
#      54         # ----------------------------------------------------------
#      55
#
# D:\Ram\PCAL\Data_Science\Projects\Trading\Oanda_Trading\bt_3ema_trader\utils\loops.py in after_lema(data)
#      57     data['lema_list'].popleft()
#      58     data['lema_list'].append(data['tick'])
# ---> 59     data['lema'] = list(pd.DataFrame(list(data['lema_list'])).ewm(span=data['lema_len']).mean()[0])[-1]
#      60
#      61     if data["plot"]:
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\pandas\core\window\ewm.py in mean(self, *args, **kwargs)
#     357                 minp=self.min_periods,
#     358             )
# --> 359         return self._apply(window_func)
#     360
#     361     @Substitution(name="ewm", func_name="std")
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\pandas\core\window\ewm.py in _apply(self, func)
#     310         for i, b in enumerate(blocks):
#     311             try:
# --> 312                 values = self._prep_values(b.values)
#     313
#     314             except (TypeError, NotImplementedError) as err:
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\pandas\core\window\rolling.py in _prep_values(self, values)
#     358
#     359         # Convert inf to nan for C funcs
# --> 360         inf = np.isinf(values)
#     361         if inf.any():
#     362             values = np.where(inf, np.nan, values)
#
# KeyboardInterrupt:

# %%
if data["plot"]:
    data = adjust_plot_list_lengths(data)
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['date_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df']['pls'].value_counts())
print('-----------------------------------------------------')
data['report_df']

winsound.PlaySound('C:\\Windows\\Media\\tada.wav', winsound.SND_ASYNC)
# Out:
# -----------------------------------------------------
# ==============================
# date_val          : ['20210101', '20210102', '20210103', '20210104', '20210105']
# Total PL : -0.00301
# -------------
# net_pl            : -0.00301/0.00301
# -------------
# +ve               : num= 0    sum= +0.0    avg= +nan
# -ve               : num= 2    sum= -0.00301    avg= -0.0015
# ==============================
# -----------------------------------------------------
# date_val
# 4   -0.00301
# Name: pls, dtype: float64
# -----------------------------------------------------
# -0.00151    1
# -0.00150    1
# Name: pls, dtype: int64
# -----------------------------------------------------
