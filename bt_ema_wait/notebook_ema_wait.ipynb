# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *
import winsound
from tqdm import tqdm
tqdm.pandas()

# %%
# %%time
data = get_date_list(data)
# data = read_data(data)
data = run_engine(data)
# Out:
#  99%|██████████████████████████████▋| 101450/102474 [00:07<00:00, 12782.73it/s]
# pls    0.00133
# dtype: float64
# --------------------------------------
#                   date ord_types               close_type      pls
# 32 2021-01-04 15:56:41     short               tick_close  0.00015
# 33 2021-01-04 16:05:57     short               sema_close -0.00027
# 34 2021-01-04 16:12:22      long  simple_slema_move_close  0.00002
# 35 2021-01-04 16:35:24      long               sema_close -0.00041
# 36 2021-01-04 17:21:56     short               tick_close  0.00112
# 37 2021-01-04 17:23:38     short  simple_slema_move_close  0.00001
# 38 2021-01-04 17:38:13     short               sema_close -0.00014
# 39 2021-01-04 17:56:34      long               sema_close -0.00044
# 40 2021-01-04 18:57:25     short               tick_close  0.00038
# 41 2021-01-04 19:04:38     short  simple_slema_move_close  0.00004
# 42 2021-01-04 19:15:32     short  simple_slema_move_close  0.00005
# 43 2021-01-04 19:59:11     short               sema_close -0.00047
# 44 2021-01-04 20:33:07      long               sema_close -0.00098
# 45 2021-01-04 21:21:29     short  simple_slema_move_close  0.00001
# 46 2021-01-04 22:57:00     short               sema_close -0.00085
# 100%|███████████████████████████████| 102474/102474 [00:07<00:00, 12909.58it/s]
# Wall time: 9.02 s

# %%
if data["plot"]:
    data = adjust_plot_list_lengths(data)
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['month_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df']['close_type'].value_counts())
print('-----------------------------------------------------')
data['report_df']

winsound.PlaySound('C:\\Windows\\Media\\tada.wav', winsound.SND_ASYNC)
# Out:
# -----------------------------------------------------
# ==============================
# date_val          : ['20210101', '20210102', '20210103', '20210104']
# Total PL : 0.0013300000000000005
# -------------
# net_pl            : 0.00133/0.01715
# -------------
# +ve               : num= 30    sum= +0.00924    avg= +0.00031
# -ve               : num= 17    sum= -0.00791    avg= -0.00047
# ==============================
# -----------------------------------------------------
# month_val
# 1    0.00133
# Name: pls, dtype: float64
# -----------------------------------------------------
# sema_close                 17
# simple_slema_move_close    15
# tick_close                 15
# Name: close_type, dtype: int64
# -----------------------------------------------------

# %% [markdown]
# import glob
#
# for file in glob.glob("data/*.csv"):
#     if file not in ['data\\eurusd_2021.csv', 'data\\full_df.csv']:
#         df = pd.read_csv(file)
#         print('----------------------------')
#         print(f'file : {file}')
#         print(df['pls'].sum())
#         print(df.groupby(['month_val'])['pls'].sum())
#         print('----------------------------')

# %%
data['report_df'][['date', 'ord_types', 'close_type', 'pls']]
# Out:
#                   date ord_types               close_type      pls
# 0  2021-01-04 03:33:10     short  simple_slema_move_close  0.00001
# 1  2021-01-04 03:56:36     short  simple_slema_move_close  0.00001
# 2  2021-01-04 05:49:51     short               tick_close  0.00034
# 3  2021-01-04 06:10:53     short               sema_close -0.00041
# 4  2021-01-04 06:37:52      long               sema_close -0.00019
# 5  2021-01-04 07:02:08     short               sema_close -0.00066
# 6  2021-01-04 07:54:27      long               tick_close  0.00040
# 7  2021-01-04 07:57:19      long  simple_slema_move_close  0.00003
# 8  2021-01-04 08:24:20      long               tick_close  0.00057
# 9  2021-01-04 09:52:15      long               tick_close  0.00235
# 10 2021-01-04 09:55:06      long  simple_slema_move_close  0.00001
# 11 2021-01-04 10:04:08      long               tick_close  0.00001
# 12 2021-01-04 10:05:20      long               tick_close  0.00001
# 13 2021-01-04 10:19:02      long               tick_close  0.00015
# 14 2021-01-04 10:30:44      long  simple_slema_move_close  0.00001
# 15 2021-01-04 10:42:25      long               sema_close -0.00017
# 16 2021-01-04 10:53:31     short  simple_slema_move_close  0.00001
# 17 2021-01-04 11:18:40     short               sema_close -0.00033
# 18 2021-01-04 11:51:11      long  simple_slema_move_close  0.00001
# 19 2021-01-04 12:09:19      long               sema_close -0.00043
# 20 2021-01-04 12:35:56     short               sema_close -0.00053
# 21 2021-01-04 13:06:47      long               tick_close  0.00008
# 22 2021-01-04 13:14:00      long  simple_slema_move_close  0.00001
# 23 2021-01-04 13:26:02      long               sema_close -0.00100
# 24 2021-01-04 13:55:00     short               sema_close -0.00050
# 25 2021-01-04 14:03:29      long               tick_close  0.00032
# 26 2021-01-04 14:08:18      long  simple_slema_move_close  0.00003
# 27 2021-01-04 14:33:39      long               tick_close  0.00027
# 28 2021-01-04 14:44:38      long  simple_slema_move_close  0.00002
# 29 2021-01-04 14:44:55      long               sema_close -0.00013
# 30 2021-01-04 14:50:01     short               tick_close  0.00002
# 31 2021-01-04 15:49:18     short               tick_close  0.00279
# 32 2021-01-04 15:56:41     short               tick_close  0.00015
# 33 2021-01-04 16:05:57     short               sema_close -0.00027
# 34 2021-01-04 16:12:22      long  simple_slema_move_close  0.00002
# 35 2021-01-04 16:35:24      long               sema_close -0.00041
# 36 2021-01-04 17:21:56     short               tick_close  0.00112
# 37 2021-01-04 17:23:38     short  simple_slema_move_close  0.00001
# 38 2021-01-04 17:38:13     short               sema_close -0.00014
# 39 2021-01-04 17:56:34      long               sema_close -0.00044
# 40 2021-01-04 18:57:25     short               tick_close  0.00038
# 41 2021-01-04 19:04:38     short  simple_slema_move_close  0.00004
# 42 2021-01-04 19:15:32     short  simple_slema_move_close  0.00005
# 43 2021-01-04 19:59:11     short               sema_close -0.00047
# 44 2021-01-04 20:33:07      long               sema_close -0.00098
# 45 2021-01-04 21:21:29     short  simple_slema_move_close  0.00001
# 46 2021-01-04 22:57:00     short               sema_close -0.00085
