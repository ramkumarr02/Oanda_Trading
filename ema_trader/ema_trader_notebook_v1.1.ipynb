# %%
# # ML Trader
import numpy as np
import pandas as pd

from scipy.stats import linregress
import math

import collections

from tqdm import tqdm

from IPython import display
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

import datetime as dt

import winsound

import warnings
warnings.filterwarnings('ignore')

import cProfile

import pstats

# %%
def before_sema(data):   
    data['sema_list'].append(data['tick'])    
    return(data)

def after_sema(data):     
    data['sema_list'].popleft()
    data['sema_list'].append(data['tick'])
    data['sema'] = list(pd.DataFrame(list(data['sema_list'])).ewm(span=data['sema_len']).mean()[0])[-1]    
    data["df_sema_list"].append(data['sema'])
    return(data)

def before_lema(data):   
    data['lema_list'].append(data['tick'])    
    return(data)

def after_lema(data):     
    data['lema_list'].popleft()
    data['lema_list'].append(data['tick'])
    data['lema'] = list(pd.DataFrame(list(data['lema_list'])).ewm(span=data['lema_len']).mean()[0])[-1]
    data["df_lema_list"].append(data['lema'])
    return(data)

# %%
def print_report(data):
    display.clear_output(wait = True)
    print('--------------------------')
    print(f'Total PL : {sum(data["pl_list"])}')
    print('-----------')
    print(data['pl_list'])
    print('--------------------------')
    return()

# %%
def read_data(data):
    source_file_path = f'..\\data\\yearly_tick_data\\{data["year"]}.csv'

    if data['input_rows'] is None:
        data["df"] = pd.read_csv(source_file_path)
    else:
        data["df"] = pd.read_csv(source_file_path, nrows=data['input_rows'])
        
    data["df"] = data["df"][data["df"]['DateTime'].str.contains('|'.join(data['date_list']))]
    
    data["df"]['tick'] = np.float()
    data["df"]['sema'] = np.float()
    data["df"]['lema'] = np.float()
    
    return(data["df"])

# %%
def get_dir(data):
    
    if data['sema'] > data['lema']:
        data['position'] = 1

    elif data['sema'] < data['lema']:
        data['position'] = -1
    
    return(data)

# %%
def after_dir(data):   
    
    data['dir_list'].popleft()
    data['dir_list'].append(data['position'])   
    
    if sum(data['dir_list']) != 0:
        data['dir_change'] = False

    elif sum(data['dir_list']) == 0:
        data['dir_change'] = True

    return(data)

# %%
def make_order(data):
    if not data['open_order']:
        if data['dir_change']:
            if data['position'] > 0 and data['angle'] >= 20:
                data['order_ask_price'] = data['ask']
                data['open_order'] = True
                data['open_order_type'] = 'long'
                
                data['buy_markers_x'].append(data['i_list'][-1])
                data['buy_markers_y'].append(data['ask'])
                
            elif data['position'] < 0 and data['angle'] <= -20:
                data['order_bid_price'] = data['bid']
                data['open_order'] = True
                data['open_order_type'] = 'short'
                
                data['buy_markers_x'].append(data['i_list'][-1])
                data['buy_markers_y'].append(data['bid'])
                
    return(data)

# %%
def close_order(data):
    if data['open_order']:
        if data['dir_change']:
            if data['position'] < 0 and data['angle'] <= -20:
                data['close_bid_price'] = data['bid']
                data['pl'] = np.round(data['close_bid_price'] - data['order_ask_price'], 4)
                data['pl_list'].append(data['pl'])
                data['dt_list'].append(data['dt_val'])
                data['open_order'] = False
                
                data['sell_markers_x'].append(data['i_list'][-1])
                data['sell_markers_y'].append(data['bid'])               
                
            elif data['position'] > 0 and data['angle'] >= 20:
                data['close_ask_price'] = data['ask']
                data['pl'] = np.round(data['order_bid_price'] - data['close_ask_price'], 4)
                data['pl_list'].append(data['pl'])
                data['dt_list'].append(data['dt_val'])
                data['open_order'] = False
                
                data['sell_markers_x'].append(data['i_list'][-1])
                data['sell_markers_y'].append(data['ask'])                  
                
    return(data)

# %%
def tick_close(data):
    if data['open_order']:
        if data['open_order_type'] == 'short':
            if data['tick'] - data['lema'] >= 0 and data['angle'] >= 20:
                data['close_ask_price'] = data['ask']
                data['pl'] = np.round(data['order_bid_price'] - data['close_ask_price'], 4)
                data['pl_list'].append(data['pl'])
                data['dt_list'].append(data['dt_val'])
                data['open_order'] = False
                
                data['sell_markers_x'].append(data['i_list'][-1])
                data['sell_markers_y'].append(data['ask'])  
                
        if data['open_order_type'] == 'long':
            if data['lema'] - data['tick'] >= 0 and data['angle'] <= -20:
                data['close_bid_price'] = data['bid']
                data['pl'] = np.round(data['close_bid_price'] - data['order_ask_price'], 4)
                data['pl_list'].append(data['pl'])
                data['dt_list'].append(data['dt_val'])
                data['open_order'] = False
                
                data['sell_markers_x'].append(data['i_list'][-1])
                data['sell_markers_y'].append(data['bid'])                  
                
    return(data)

# %%
def get_date_list(data):
    
    data['start_date'] = dt.datetime(year=data['start_date']['year'],
                      month=data['start_date']['month'],
                      day=data['start_date']['date'])

    data['end_date'] = dt.datetime(year=data['end_date']['year'],
                      month=data['end_date']['month'],
                      day=data['end_date']['date'])

    
    date_list = list(pd.date_range(data['start_date'],data['end_date'],freq='d').values)
    data['date_list'] = [str(x).split('T')[0].replace('-','') for x in date_list]
    return(data)

# %%
def get_run_duration(data):
    run_time = len(data["date_list"]) * 6
    hours = run_time//60
    mins = run_time%60
    print(f'Approx run time : {hours}-hours : {mins}-mins')

# %%
def split_date_col(data):
    data['total_df']['year_val'] = [x.year for x in data['total_df']['date']]
    data['total_df']['month_val'] = [x.month for x in data['total_df']['date']]
    data['total_df']['date_val'] = [x.day for x in data['total_df']['date']]
    data['total_df']['hour_val'] = [x.hour for x in data['total_df']['date']]
    data['total_df']['minute_val'] = [x.minute for x in data['total_df']['date']]

# %%
def get_date_lines(data):
    data['line_list'] = []
    
    for dt_val  in data['date_list']:    
        data['line_list'].append(data["df"][data["df"]['DateTime'].str.contains(dt_val)].index[0])
    
    return(data)

# %%
def plot_graph(data):
    fig, ax1 = plt.subplots(figsize=(50,10))
    ax2 = ax1.twinx()

    x_axis = np.arange(0,len(data["df"]['tick']))

    ax1.plot(x_axis, data["df"]['tick'], label='tick', color='green', linestyle='dotted')
    ax1.plot(x_axis, data["df"]['sema'], label='sema', color='black')
    ax1.plot(x_axis, data["df"]['lema'], label='lema', color='blue')

    data = get_date_lines(data)

    for x_val in data['line_list']:
        plt.axvline(x=x_val, color='black')

    ax1.scatter(data['buy_markers_x'], data['buy_markers_y'], s=300, c='b')
    ax1.scatter(data['sell_markers_x'], data['sell_markers_y'], s=300, c='r')

    ax2.plot(data['df']["angle"], c='g', label = 'angle', linestyle = 'dashed')

    legend = ax1.legend(loc='upper left', fontsize='xx-large')
    legend = ax2.legend(loc='upper right', fontsize='xx-large')
    
    ax1.tick_params(axis='x', colors='red', labelsize = 25)
    ax1.tick_params(axis='y', colors='red', labelsize = 25)
    ax2.tick_params(axis='y', colors='red', labelsize = 25)


    plt.xlabel('tick num')
    plt.ylabel('prices')
    plt.title('trade chart')
    plt.grid()
    plt.show()

# %%
def print_report(data):
    pl_list = list(data['pl_list'])
    net_pl = round(np.sum(pl_list),5)

    positive_pls = [i for i in pl_list if i > 0]
    negative_pls = [i for i in pl_list if i < 0]

    num_positive = len(positive_pls)
    num_negative = len(negative_pls)

    sum_positive = round(np.sum(positive_pls),5)
    sum_negative = round(np.sum(negative_pls),5)
    sum_total    = round(sum_positive + abs(sum_negative),5) 

    avg_positive = round(np.mean(positive_pls),5)
    avg_negative = round(np.mean(negative_pls),5)

    
    print('==============================')
    print(f'date_val          : {data["date_list"]}')    
    print(f'Total PL : {sum(data["pl_list"])}')
    print('-------------')
    print(f'net_pl            : {net_pl}/{sum_total}')  
    print('-------------')
    print(f'+ve               : num= {num_positive}    sum= +{sum_positive}    avg= +{avg_positive}')
    print(f'-ve               : num= {num_negative}    sum= {sum_negative}    avg= {avg_negative}')
    print('==============================')

# %%
def get_slope(data):
    pip_decimal_num = 6
    
    data['y_axis'] = list(np.round(data['y_axis'],pip_decimal_num))
    ma_len = len(data['y_axis'])
    
    x_axis = []
    for i in range(ma_len):
        x_axis.append(1 + ((i+1) * 10**(-pip_decimal_num)))
    
    slope_tick, intercept, _, _, _ = linregress(x_axis, data['y_axis'])
    data['angle'] = math.degrees(math.atan(slope_tick))
    data['angle_list'].append(data['angle'])
    
    return(data)

# %%
def run_engine(data):
    for i in tqdm(range(0, len(data["df"]))):
        
        data['ask'] = data["df"]['Ask'][i]
        data['bid'] = data["df"]['Bid'][i]
        data['tick'] = (data['ask'] + data['bid'])/2    
        data["tick_list"].append(data['tick'])
        
        data['dt_val'] = dt.datetime.strptime(data["df"]['DateTime'][i].split(".")[0],"%Y%m%d %H:%M:%S")

        # sema before after loops --------------------------------
        if len(data['sema_list']) < data['sema_len']:
            data =  before_sema(data)

        if len(data['sema_list']) == data['sema_len']:
            data = after_sema(data)                 
        # ----------------------------------------------------------


        # Get Angle --------------------------------
        data['y_axis'] = list(data["tick_list"][-data['angle_len']:])        
        if 0 not in data['y_axis']:            
            if len(data['y_axis']) >= data['angle_len']:
                data = get_slope(data)            
        # ----------------------------------------------------------         
                       
                
            
        # lema before after loops --------------------------------
        if len(data['lema_list']) < data['lema_len']:
            data = before_lema(data)        
            continue

        if len(data['lema_list']) == data['lema_len']:
            data = after_lema(data)                  
        # ----------------------------------------------------------
       
             
        data['i_list'].append(i)
        data = get_dir(data)

        # Get Dirs --------------------------------
        if len(data['dir_list']) < 2:
            data['dir_list'].append(data['position'])   
            continue
            
        elif len(data['dir_list']) == 2:
            data = after_dir(data)
        # ----------------------------------------------------------

        
        data = tick_close(data)
        data = close_order(data)
        data = make_order(data)    

    
    # Adjust df len to lema(shortest) len
    data["df"] = data['df'][-len(data["df_lema_list"]):]   
    data["df"] = data["df"].reset_index(drop = True)    
    
    # Assign sema, lema and tick to df
    data["df"]['lema'] = data["df_lema_list"]            
    data["df"]['sema'] = list(data["df_sema_list"])[-len(data["df_lema_list"]):]    
    data['df']["tick"] = list(data["tick_list"])[-len(data["df_lema_list"]):]
    data['df']["angle"] = list(data["angle_list"])[-len(data["df_lema_list"]):]
    
    # Adjust buy sell markers to the shortened df
    data['len_to_subtract'] = data['lema_len']
    data['buy_markers_x'] = list(np.array(data['buy_markers_x']) - data['len_to_subtract'])
    data['sell_markers_x'] = list(np.array(data['sell_markers_x']) - data['len_to_subtract'])    
    data["df"] = data["df"].reset_index(drop = True)
    
    return()

# %%
data = {}
data["year"] = 2021
data['total_df'] = pd.DataFrame()
data['sema_list'] = collections.deque()
data['lema_list'] = collections.deque()
data['dir_list'] = collections.deque()
data['pl_list'] =  collections.deque()
data['dt_list'] =  collections.deque()
data['angle_list'] = []
data['tick_list'] = []
data['df_sema_list'] = []
data['df_lema_list'] = []

data['i_list'] = []


data['buy_markers_x'] = []
data['buy_markers_y'] = []

data['sell_markers_x'] = []
data['sell_markers_y'] = []

data['open_order_type'] = None

# %%
data['input_rows'] = None

data['start_date'] = {'year':2021, 'month':2, 'date':8}
data['end_date']   = {'year':2021, 'month':2, 'date':12}

data['sema_len'] = 2000
data['lema_len'] = 50000

data['angle_len'] = 2000

# %%
# %%time
data = get_date_list(data)
read_data(data)
data["df"] = data["df"][0:6000]
print(f'Record num : {len(data["df"])}')    
data["df"] = data["df"].reset_index(drop = True)
data['df']['i'] = np.int()
data['open_order'] = False    
data = run_engine(data)

plot_graph(data)
print_report(data)
data['total_df'] = pd.DataFrame({'date':data['dt_list'], 'pls': data['pl_list']})
split_date_col(data)
data['total_df'] = data['total_df'][['date', 'year_val', 'month_val', 'date_val', 'hour_val','minute_val', 'pls']]
data["total_df"] = data["total_df"].reset_index(drop = True)    
data['file_name'] = f'data\{data["start_date"].year}-{data["start_date"].month}-({data["start_date"].day}-{data["end_date"].day}).csv'

data['total_df'].to_csv(data['file_name'], index = False)
# Out:
#  12%|████▊                                  | 737/6000 [00:00<00:00, 6909.32it/s]
# Record num : 6000
# 100%|███████████████████████████████████████| 6000/6000 [00:19<00:00, 314.96it/s]
#          20814456 function calls (20601314 primitive calls) in 19.041 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      4001    0.003    0.000    0.047    0.000 <__array_function__ internals>:2(any)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(append)
#      5001    0.005    0.000    0.465    0.000 <__array_function__ internals>:2(apply_along_axis)
#      4001    0.004    0.000    0.777    0.000 <__array_function__ internals>:2(around)
#     10002    0.009    0.000    0.108    0.000 <__array_function__ internals>:2(array_equal)
#      4001    0.003    0.000    0.032    0.000 <__array_function__ internals>:2(atleast_1d)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_2d)
#      4001    0.003    0.000    0.160    0.000 <__array_function__ internals>:2(average)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(bincount)
#      4001    0.004    0.000    0.063    0.000 <__array_function__ internals>:2(broadcast_to)
#     14007    0.014    0.000    0.064    0.000 <__array_function__ internals>:2(concatenate)
#     10006    0.010    0.000    0.033    0.000 <__array_function__ internals>:2(copyto)
#      4001    0.004    0.000    0.365    0.000 <__array_function__ internals>:2(cov)
#      4001    0.003    0.000    0.040    0.000 <__array_function__ internals>:2(dot)
#      5001    0.005    0.000    0.023    0.000 <__array_function__ internals>:2(empty_like)
#      8002    0.005    0.000    0.147    0.000 <__array_function__ internals>:2(extract)
#      8002    0.007    0.000    0.128    0.000 <__array_function__ internals>:2(mean)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#      8002    0.004    0.000    0.024    0.000 <__array_function__ internals>:2(nonzero)
#     12003    0.007    0.000    0.045    0.000 <__array_function__ internals>:2(place)
#     16006    0.008    0.000    0.059    0.000 <__array_function__ internals>:2(ravel)
#      4001    0.003    0.000    0.013    0.000 <__array_function__ internals>:2(result_type)
#      4001    0.004    0.000    0.790    0.000 <__array_function__ internals>:2(round_)
#      4001    0.004    0.000    0.012    0.000 <__array_function__ internals>:2(shape)
#      5001    0.004    0.000    0.031    0.000 <__array_function__ internals>:2(sort)
#      8002    0.005    0.000    0.032    0.000 <__array_function__ internals>:2(take)
#     10002    0.008    0.000    0.037    0.000 <__array_function__ internals>:2(transpose)
#      5001    0.004    0.000    0.063    0.000 <__array_function__ internals>:2(zeros_like)
#      5002    0.010    0.000    0.011    0.000 <frozen importlib._bootstrap>:103(release)
#      5002    0.003    0.000    0.003    0.000 <frozen importlib._bootstrap>:143(__init__)
#      5002    0.005    0.000    0.060    0.000 <frozen importlib._bootstrap>:147(__enter__)
#      5002    0.003    0.000    0.014    0.000 <frozen importlib._bootstrap>:151(__exit__)
#      5002    0.016    0.000    0.044    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#      5002    0.005    0.000    0.007    0.000 <frozen importlib._bootstrap>:176(cb)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#    275061    0.048    0.000    0.048    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:307(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:311(__enter__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:318(__exit__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:35(_new_module)
#      5002    0.004    0.000    0.004    0.000 <frozen importlib._bootstrap>:369(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:403(cached)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:424(has_location)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:564(module_from_spec)
#      5002    0.006    0.000    0.026    0.000 <frozen importlib._bootstrap>:58(__init__)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:651(_load_unlocked)
#      5002    0.003    0.000    0.009    0.000 <frozen importlib._bootstrap>:707(find_spec)
#      5002    0.010    0.000    0.011    0.000 <frozen importlib._bootstrap>:78(acquire)
#      5002    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap>:780(find_spec)
#     20007    0.005    0.000    0.007    0.000 <frozen importlib._bootstrap>:843(__enter__)
#     20007    0.006    0.000    0.009    0.000 <frozen importlib._bootstrap>:847(__exit__)
#      5001    0.003    0.000    0.005    0.000 <frozen importlib._bootstrap>:861(_find_spec_legacy)
#      5002    0.044    0.000    2.579    0.001 <frozen importlib._bootstrap>:870(_find_spec)
#      5002    0.013    0.000    2.598    0.001 <frozen importlib._bootstrap>:936(_find_and_load_unlocked)
#      5002    0.033    0.000    2.716    0.001 <frozen importlib._bootstrap>:966(_find_and_load)
#     40028    0.029    0.000    0.056    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#     60013    0.022    0.000    0.028    0.000 <frozen importlib._bootstrap_external>:1080(_path_importer_cache)
#      5002    0.081    0.000    2.496    0.000 <frozen importlib._bootstrap_external>:1117(_get_spec)
#      5002    0.005    0.000    2.500    0.000 <frozen importlib._bootstrap_external>:1149(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1228(_get_spec)
#     55012    0.303    0.000    2.362    0.000 <frozen importlib._bootstrap_external>:1233(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1281(_fill_cache)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1310(<setcomp>)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:263(cache_from_source)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:361(_get_cached)
#     55012    0.017    0.000    0.017    0.000 <frozen importlib._bootstrap_external>:37(_relax_case)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:393(_check_name_wrapper)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:430(_validate_bytecode_header)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:485(_compile_bytecode)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:52(_r_long)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:524(spec_from_file_location)
#    275060    0.121    0.000    0.326    0.000 <frozen importlib._bootstrap_external>:57(_path_join)
#    275060    0.108    0.000    0.167    0.000 <frozen importlib._bootstrap_external>:59(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:63(_path_split)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:669(create_module)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:672(exec_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:743(get_code)
#     55014    0.024    0.000    1.661    0.000 <frozen importlib._bootstrap_external>:75(_path_stat)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:800(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:825(get_filename)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:830(get_data)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:840(path_stats)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:85(_path_is_mode_type)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:94(_path_isfile)
#      4001    3.019    0.001    6.056    0.002 <ipython-input-16-6a408c7135d2>:1(get_slope)
#         1    2.064    2.064   19.041   19.041 <ipython-input-17-b9dfead729dd>:1(run_engine)
#      2000    0.001    0.000    0.001    0.000 <ipython-input-2-03bae3d1171a>:1(before_sema)
#      5000    0.002    0.000    0.003    0.000 <ipython-input-2-03bae3d1171a>:12(before_lema)
#      1000    0.384    0.000    2.477    0.002 <ipython-input-2-03bae3d1171a>:16(after_lema)
#      4001    0.656    0.000    7.886    0.002 <ipython-input-2-03bae3d1171a>:5(after_sema)
#      1000    0.001    0.000    0.001    0.000 <ipython-input-5-6e5ea283aff0>:1(get_dir)
#       998    0.001    0.000    0.002    0.000 <ipython-input-6-7a03f35f3453>:1(after_dir)
#       998    0.000    0.000    0.000    0.000 <ipython-input-7-a2c3b08e5139>:1(make_order)
#       998    0.000    0.000    0.000    0.000 <ipython-input-8-6c3b52e71459>:1(close_order)
#       998    0.000    0.000    0.000    0.000 <ipython-input-9-54fe13375782>:1(tick_close)
#         1    0.000    0.000   19.041   19.041 <string>:1(<module>)
#      4001    0.003    0.000    0.005    0.000 <string>:12(__new__)
#      4001    0.001    0.000    0.001    0.000 <string>:2(_parse_args)
#         2    0.000    0.000    0.000    0.000 __init__.py:358(__getattr__)
#         2    0.000    0.000    0.000    0.000 __init__.py:365(__getitem__)
#         1    0.000    0.000    0.000    0.000 __init__.py:47(create_string_buffer)
# 110033/110032    0.032    0.000    1.291    0.000 _asarray.py:16(asarray)
#      5001    0.017    0.000    0.031    0.000 _asarray.py:223(require)
#      5001    0.005    0.000    0.006    0.000 _asarray.py:300(<setcomp>)
#     55021    0.016    0.000    0.040    0.000 _asarray.py:88(asanyarray)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:252(__subclasshook__)
#         7    0.000    0.000    0.000    0.000 _collections_abc.py:271(__subclasshook__)
#        15    0.000    0.000    0.000    0.000 _collections_abc.py:302(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:349(__subclasshook__)
#         4    0.000    0.000    0.000    0.000 _collections_abc.py:367(__subclasshook__)
#        57    0.000    0.000    0.000    0.000 _collections_abc.py:392(__subclasshook__)
#        10    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
#      4001    0.008    0.000    0.008    0.000 _continuous_distns.py:5738(_argcheck)
#      4001    0.018    0.000    0.018    0.000 _continuous_distns.py:5762(_sf)
#      5001    0.005    0.000    1.234    0.000 _decorators.py:307(wrapper)
#      4001    0.113    0.000    0.572    0.000 _distn_infrastructure.py:1882(sf)
#      4001    0.017    0.000    0.220    0.000 _distn_infrastructure.py:520(argsreduce)
#      4001    0.023    0.000    0.170    0.000 _distn_infrastructure.py:545(<listcomp>)
#      8002    0.002    0.000    0.002    0.000 _distn_infrastructure.py:876(_get_support)
#      4001    0.012    0.000    0.014    0.000 _distn_infrastructure.py:901(_open_support_mask)
#      5003    0.006    0.000    0.024    0.000 _dtype.py:319(_name_includes_bit_suffix)
#      5003    0.015    0.000    0.045    0.000 _dtype.py:333(_name_get)
#      5003    0.002    0.000    0.002    0.000 _dtype.py:36(_kind_name)
#      5001    0.015    0.000    0.060    0.000 _dtype.py:46(__str__)
#         3    0.000    0.000    0.000    0.000 _internal.py:830(npy_ctypes_check)
#     12003    0.067    0.000    0.163    0.000 _methods.py:134(_mean)
#     14004    0.005    0.000    0.057    0.000 _methods.py:44(_any)
#     10002    0.004    0.000    0.035    0.000 _methods.py:47(_all)
#     12003    0.020    0.000    0.022    0.000 _methods.py:50(_count_reduce_items)
#         1    0.000    0.000    0.000    0.000 _monitor.py:30(__init__)
#      4001    0.092    0.000    1.875    0.000 _stats_mstats_common.py:15(linregress)
#         1    0.000    0.000    0.000    0.000 _strptime.py:250(pattern)
#         1    0.000    0.000    0.001    0.001 _strptime.py:273(compile)
#      6000    0.004    0.000    0.035    0.000 _strptime.py:29(_getlang)
#      6000    0.069    0.000    0.135    0.000 _strptime.py:321(_strptime)
#      6000    0.012    0.000    0.147    0.000 _strptime.py:562(_strptime_datetime)
#      5003    0.002    0.000    0.003    0.000 _validators.py:208(validate_bool_kwarg)
#      5001    0.015    0.000    0.031    0.000 _validators.py:218(validate_axis_style_args)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:106(remove)
#       127    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#       127    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#       127    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#       127    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#       186    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#     40420    0.021    0.000    0.021    0.000 _weakrefset.py:70(__contains__)
#       127    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#     25006    0.029    0.000    0.052    0.000 abc.py:180(__instancecheck__)
#     205/3    0.001    0.000    0.002    0.001 abc.py:196(__subclasscheck__)
#      5001    0.008    0.000    0.065    0.000 api.py:109(_get_combined_index)
#      5001    0.005    0.000    0.079    0.000 api.py:65(get_objs_combined_axis)
#      5001    0.004    0.000    0.009    0.000 api.py:91(<listcomp>)
#      5001    0.008    0.000    0.011    0.000 api.py:95(_get_distinct_objs)
#      5001    0.015    0.000    0.035    0.000 base.py:1032(__iter__)
#     35014    0.006    0.000    0.006    0.000 base.py:1175(name)
#     15008    0.012    0.000    0.048    0.000 base.py:1182(name)
#     23001    0.003    0.000    0.003    0.000 base.py:1378(nlevels)
#         1    0.000    0.000    0.000    0.000 base.py:1646(is_unique)
#         2    0.000    0.000    0.000    0.000 base.py:1720(is_integer)
#         7    0.000    0.000    0.000    0.000 base.py:1755(is_floating)
#      5001    0.004    0.000    0.004    0.000 base.py:190(_selected_obj)
#     18000    0.008    0.000    0.010    0.000 base.py:1994(holds_integer)
#         1    0.000    0.000    0.000    0.000 base.py:2000(inferred_type)
#    150052    0.077    0.000    0.439    0.000 base.py:256(is_dtype)
#         7    0.000    0.000    0.000    0.000 base.py:2854(get_loc)
# 5005/5003    0.044    0.000    0.250    0.000 base.py:293(__new__)
#         1    0.000    0.000    0.000    0.000 base.py:3127(_convert_slice_indexer)
#         3    0.000    0.000    0.000    0.000 base.py:3145(is_int)
#      5001    0.010    0.000    0.403    0.000 base.py:3294(reindex)
#     30011    0.010    0.000    0.041    0.000 base.py:3873(_values)
#         1    0.000    0.000    0.000    0.000 base.py:3899(_get_engine_target)
#         1    0.000    0.000    0.000    0.000 base.py:3983(_coerce_scalar_to_index)
#     18009    0.014    0.000    0.016    0.000 base.py:4039(__contains__)
#         3    0.000    0.000    0.000    0.000 base.py:4086(__getitem__)
#     65032    0.049    0.000    0.069    0.000 base.py:413(find)
#      5001    0.014    0.000    0.501    0.000 base.py:4136(append)
#      5001    0.003    0.000    0.004    0.000 base.py:4159(<setcomp>)
#      5001    0.014    0.000    0.481    0.000 base.py:4164(_concat)
#      5001    0.003    0.000    0.005    0.000 base.py:4168(<listcomp>)
#     10002    0.037    0.000    0.817    0.000 base.py:4199(equals)
#         2    0.000    0.000    0.000    0.000 base.py:424(<genexpr>)
#      5001    0.009    0.000    0.458    0.000 base.py:4278(identical)
#     10002    0.004    0.000    0.009    0.000 base.py:4292(<genexpr>)
#     18000    0.007    0.000    0.018    0.000 base.py:4618(_should_fallback_to_positional)
#     18000    0.014    0.000    0.041    0.000 base.py:4626(_get_values_for_loc)
#     10006    0.017    0.000    0.025    0.000 base.py:463(_simple_new)
#         1    0.000    0.000    0.000    0.000 base.py:492(_get_attributes_dict)
#         1    0.000    0.000    0.000    0.000 base.py:496(<dictcomp>)
#         7    0.000    0.000    0.000    0.000 base.py:4979(_maybe_cast_indexer)
#         2    0.000    0.000    0.000    0.000 base.py:498(_shallow_copy)
#         3    0.000    0.000    0.000    0.000 base.py:4988(_validate_indexer)
#     10002    0.005    0.000    0.007    0.000 base.py:520(is_)
#         1    0.000    0.000    0.000    0.000 base.py:5240(insert)
#     25014    0.012    0.000    0.012    0.000 base.py:544(_reset_identity)
#         1    0.000    0.000    0.000    0.000 base.py:554(_engine)
#     70022    0.019    0.000    0.028    0.000 base.py:5562(ensure_index)
#         1    0.000    0.000    0.000    0.000 base.py:561(<lambda>)
#      5001    0.002    0.000    0.007    0.000 base.py:5626(ensure_has_len)
#     10004    0.021    0.000    0.194    0.000 base.py:5653(default_index)
#     35018    0.024    0.000    0.085    0.000 base.py:5659(maybe_extract_name)
#     35014    0.011    0.000    0.015    0.000 base.py:567(__len__)
#         2    0.000    0.000    0.000    0.000 base.py:5675(_maybe_cast_with_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:5729(_maybe_cast_data_without_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:573(__array__)
#      5002    0.001    0.000    0.001    0.000 base.py:590(dtype)
#         4    0.000    0.000    0.000    0.000 base.py:613(view)
#      5001    0.010    0.000    0.070    0.000 base.py:701(take)
#         7    0.000    0.000    0.000    0.000 blocks.py:111(_simple_new)
#     30025    0.061    0.000    0.125    0.000 blocks.py:124(__init__)
#     30025    0.014    0.000    0.014    0.000 blocks.py:135(_check_ndim)
#     33003    0.005    0.000    0.005    0.000 blocks.py:201(internal_values)
#      5001    0.003    0.000    0.015    0.000 blocks.py:213(get_values)
#     75063    0.012    0.000    0.012    0.000 blocks.py:233(mgr_locs)
#     35026    0.042    0.000    0.078    0.000 blocks.py:237(mgr_locs)
#         3    0.000    0.000    0.000    0.000 blocks.py:2396(__init__)
#     20022    0.028    0.000    0.106    0.000 blocks.py:256(make_block_same_class)
#     10003    0.032    0.000    0.265    0.000 blocks.py:2677(get_block_type)
#     10003    0.022    0.000    0.349    0.000 blocks.py:2723(make_block)
#      5016    0.004    0.000    0.007    0.000 blocks.py:2750(_extend_blocks)
#         7    0.000    0.000    0.000    0.000 blocks.py:287(_slice)
#         7    0.000    0.000    0.000    0.000 blocks.py:292(getitem_block)
#     15003    0.006    0.000    0.006    0.000 blocks.py:311(shape)
#     25008    0.007    0.000    0.007    0.000 blocks.py:315(dtype)
#      5004    0.003    0.000    0.003    0.000 blocks.py:319(iget)
#         3    0.000    0.000    0.000    0.000 blocks.py:322(set)
#         3    0.000    0.000    0.000    0.000 blocks.py:642(should_store)
#     10017    0.008    0.000    0.061    0.000 blocks.py:675(copy)
#      5006    0.275    0.000    0.323    0.000 cast.py:1570(construct_1d_object_array_from_listlike)
#      5005    0.031    0.000    1.340    0.000 cast.py:88(maybe_convert_platform)
#     40008    0.028    0.000    0.103    0.000 common.py:1025(is_datetime_or_timedelta_dtype)
#     10002    0.011    0.000    0.256    0.000 common.py:1123(is_datetimelike_v_numeric)
#     40008    0.028    0.000    0.436    0.000 common.py:1180(needs_i8_conversion)
#     15008    0.011    0.000    0.030    0.000 common.py:1296(is_float_dtype)
#      5004    0.007    0.000    0.026    0.000 common.py:1330(is_bool_dtype)
#     65032    0.054    0.000    0.152    0.000 common.py:1460(is_extension_array_dtype)
#        10    0.000    0.000    0.000    0.000 common.py:149(cast_scalar_indexer)
#     25009    0.015    0.000    0.018    0.000 common.py:150(ensure_python_int)
#     10002    0.006    0.000    0.016    0.000 common.py:1509(is_complex_dtype)
#     20004    0.011    0.000    0.025    0.000 common.py:1541(_is_dtype)
#     35016    0.010    0.000    0.014    0.000 common.py:1565(_get_dtype)
#    105040    0.082    0.000    0.163    0.000 common.py:1600(_is_dtype_type)
#     30012    0.016    0.000    0.022    0.000 common.py:1733(pandas_dtype)
#      5001    0.002    0.000    0.002    0.000 common.py:176(not_none)
#    100031    0.018    0.000    0.018    0.000 common.py:178(classes)
#     10002    0.002    0.000    0.002    0.000 common.py:180(<genexpr>)
#    100031    0.023    0.000    0.038    0.000 common.py:180(<lambda>)
#      5009    0.001    0.000    0.001    0.000 common.py:183(classes_and_not_datetimelike)
#      5009    0.003    0.000    0.005    0.000 common.py:188(<lambda>)
#     10004    0.011    0.000    0.019    0.000 common.py:190(all_none)
#     20008    0.004    0.000    0.004    0.000 common.py:194(<genexpr>)
#     30010    0.030    0.000    0.093    0.000 common.py:194(is_object_dtype)
#     10002    0.007    0.000    0.023    0.000 common.py:211(count_not_none)
#     40008    0.006    0.000    0.006    0.000 common.py:215(<genexpr>)
#         4    0.000    0.000    0.000    0.000 common.py:218(asarray_tuplesafe)
#     15004    0.021    0.000    0.048    0.000 common.py:224(is_sparse)
#     41006    0.012    0.000    0.016    0.000 common.py:329(apply_if_callable)
#      5001    0.003    0.000    0.004    0.000 common.py:348(is_datetime64_dtype)
#     55012    0.029    0.000    0.195    0.000 common.py:381(is_datetime64tz_dtype)
#     15011    0.009    0.000    0.016    0.000 common.py:422(is_timedelta64_dtype)
#     60021    0.034    0.000    0.235    0.000 common.py:456(is_period_dtype)
#     20013    0.012    0.000    0.075    0.000 common.py:492(is_interval_dtype)
#     45018    0.025    0.000    0.117    0.000 common.py:530(is_categorical_dtype)
#     20004    0.016    0.000    0.041    0.000 common.py:566(is_string_dtype)
#     20004    0.006    0.000    0.006    0.000 common.py:595(condition)
#      5004    0.003    0.000    0.007    0.000 common.py:608(is_dtype_equal)
#         2    0.000    0.000    0.000    0.000 common.py:696(is_integer_dtype)
#      5004    0.004    0.000    0.014    0.000 common.py:750(is_signed_integer_dtype)
#         3    0.000    0.000    0.000    0.000 common.py:806(is_unsigned_integer_dtype)
#     10010    0.004    0.000    0.006    0.000 common.py:905(is_datetime64_any_dtype)
#      5001    0.023    0.000    0.213    0.000 concat.py:110(concat_compat)
#      5001    0.003    0.000    0.003    0.000 concat.py:128(is_nonempty)
#      5001    0.002    0.000    0.005    0.000 concat.py:139(<listcomp>)
#     10002    0.003    0.000    0.006    0.000 concat.py:144(<genexpr>)
#      5001    0.002    0.000    0.002    0.000 concat.py:147(<setcomp>)
#     10002    0.003    0.000    0.013    0.000 concat.py:148(<genexpr>)
#      5001    0.002    0.000    0.002    0.000 concat.py:174(__init__)
#      5001    0.019    0.000    0.135    0.000 concat.py:29(get_dtype_kinds)
#      5001    0.063    0.000    0.820    0.000 concat.py:295(__init__)
#      5001    0.021    0.000    0.178    0.000 concat.py:31(concatenate_block_managers)
#      5001    0.005    0.000    0.019    0.000 concat.py:380(<listcomp>)
#      5001    0.033    0.000    0.238    0.000 concat.py:456(get_result)
#      5001    0.003    0.000    0.048    0.000 concat.py:49(<listcomp>)
#      5001    0.003    0.000    0.006    0.000 concat.py:511(_get_result_dim)
#      5001    0.008    0.000    0.636    0.000 concat.py:517(_get_new_axes)
#      5001    0.008    0.000    0.622    0.000 concat.py:520(<listcomp>)
#      5001    0.008    0.000    0.092    0.000 concat.py:524(_get_comb_axis)
#     10002    0.005    0.000    0.005    0.000 concat.py:525(_combine_concat_plans)
#      5001    0.009    0.000    0.522    0.000 concat.py:534(_get_concat_axis)
#      5001    0.003    0.000    0.006    0.000 concat.py:567(<listcomp>)
#      5001    0.001    0.000    0.001    0.000 concat.py:584(_maybe_check_integrity)
#      5001    0.005    0.000    0.507    0.000 concat.py:591(_concat_indexes)
#      5001    0.014    0.000    1.073    0.000 concat.py:70(concat)
#      5001    0.018    0.000    0.044    0.000 concat.py:87(_get_mgr_concatenation_plan)
#     10002    0.057    0.000    2.398    0.000 construction.py:143(init_ndarray)
#     10002    0.027    0.000    1.404    0.000 construction.py:289(_prep_ndarray)
#      5001    0.003    0.000    1.343    0.000 construction.py:297(convert)
#         3    0.000    0.000    0.000    0.000 construction.py:339(extract_array)
#     10002    0.011    0.000    0.209    0.000 construction.py:450(_get_axes)
#         4    0.000    0.000    0.000    0.000 construction.py:741(sanitize_index)
#         1    0.000    0.000    0.000    0.000 context.py:196(get_start_method)
#         1    0.000    0.000    0.000    0.000 context.py:232(get_context)
#         1    0.000    0.000    0.001    0.001 context.py:69(RLock)
#     15010    0.017    0.000    0.062    0.000 dtypes.py:1119(is_dtype)
#     55018    0.039    0.000    0.195    0.000 dtypes.py:906(is_dtype)
#       378    0.000    0.000    0.000    0.000 enum.py:265(__call__)
#       378    0.000    0.000    0.000    0.000 enum.py:515(__new__)
#         9    0.000    0.000    0.000    0.000 enum.py:795(__or__)
#       180    0.000    0.000    0.001    0.000 enum.py:801(__and__)
#      5001    0.010    0.000    0.034    0.000 ewm.py:199(__init__)
#      5001    0.047    0.000    4.001    0.001 ewm.py:292(_apply)
#      5001    0.009    0.000    0.021    0.000 ewm.py:32(get_center_of_mass)
#      5001    0.026    0.000    4.037    0.001 ewm.py:330(mean)
#         7    0.000    0.000    0.000    0.000 frame.py:1099(__len__)
#     23002    0.080    0.000    0.485    0.000 frame.py:2869(__getitem__)
#         4    0.000    0.000    0.001    0.000 frame.py:3028(__setitem__)
#         4    0.000    0.000    0.001    0.000 frame.py:3109(_set_item)
#         4    0.000    0.000    0.000    0.000 frame.py:3162(_ensure_valid_index)
#      5004    0.012    0.000    0.085    0.000 frame.py:3184(_box_col_values)
#         4    0.000    0.000    0.001    0.000 frame.py:3702(_sanitize_column)
#      5001    0.005    0.000    0.581    0.000 frame.py:3871(_reindex_axes)
#      5001    0.013    0.000    0.576    0.000 frame.py:3908(_reindex_columns)
#      5001    0.015    0.000    1.229    0.000 frame.py:4017(reindex)
#     15006    0.003    0.000    0.003    0.000 frame.py:421(_constructor)
#     25008    0.074    0.000    5.302    0.000 frame.py:441(__init__)
#         2    0.000    0.000    0.000    0.000 frame.py:4621(reset_index)
#     10002    0.005    0.000    0.005    0.000 frame.py:568(axes)
#      5001    0.004    0.000    0.012    0.000 frame.py:585(shape)
#     16006    0.002    0.000    0.002    0.000 fromnumeric.py:1689(_ravel_dispatcher)
#     16006    0.014    0.000    0.040    0.000 fromnumeric.py:1693(ravel)
#      8002    0.001    0.000    0.001    0.000 fromnumeric.py:1800(_nonzero_dispatcher)
#      8002    0.004    0.000    0.016    0.000 fromnumeric.py:1804(nonzero)
#      4001    0.001    0.000    0.001    0.000 fromnumeric.py:1899(_shape_dispatcher)
#      4001    0.002    0.000    0.002    0.000 fromnumeric.py:1903(shape)
#      4001    0.001    0.000    0.001    0.000 fromnumeric.py:2232(_any_dispatcher)
#      4001    0.004    0.000    0.039    0.000 fromnumeric.py:2236(any)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3033(_ndim_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3037(ndim)
#      8002    0.001    0.000    0.001    0.000 fromnumeric.py:3126(_around_dispatcher)
#      4001    0.004    0.000    0.770    0.000 fromnumeric.py:3130(around)
#      8002    0.001    0.000    0.001    0.000 fromnumeric.py:3227(_mean_dispatcher)
#      8002    0.015    0.000    0.114    0.000 fromnumeric.py:3231(mean)
#      4001    0.004    0.000    0.781    0.000 fromnumeric.py:3590(round_)
#      4001    0.010    0.000    0.757    0.000 fromnumeric.py:42(_wrapit)
#     30007    0.022    0.000    0.812    0.000 fromnumeric.py:55(_wrapfunc)
#     10002    0.002    0.000    0.002    0.000 fromnumeric.py:600(_transpose_dispatcher)
#     10002    0.006    0.000    0.023    0.000 fromnumeric.py:604(transpose)
#      4001    0.010    0.000    0.035    0.000 fromnumeric.py:73(_wrapreduction)
#      4001    0.002    0.000    0.002    0.000 fromnumeric.py:74(<dictcomp>)
#      5001    0.001    0.000    0.001    0.000 fromnumeric.py:833(_sort_dispatcher)
#      5001    0.006    0.000    0.022    0.000 fromnumeric.py:837(sort)
#      8002    0.001    0.000    0.001    0.000 fromnumeric.py:93(_take_dispatcher)
#      8002    0.006    0.000    0.023    0.000 fromnumeric.py:97(take)
#      5001    0.006    0.000    0.006    0.000 function.py:317(validate_window_func)
#      8002    0.001    0.000    0.001    0.000 function_base.py:1624(_extract_dispatcher)
#      8002    0.019    0.000    0.134    0.000 function_base.py:1628(extract)
#     12003    0.002    0.000    0.002    0.000 function_base.py:1680(_place_dispatcher)
#     12003    0.008    0.000    0.025    0.000 function_base.py:1684(place)
#      4001    0.001    0.000    0.001    0.000 function_base.py:2240(_cov_dispatcher)
#      4001    0.097    0.000    0.354    0.000 function_base.py:2245(cov)
#      4001    0.002    0.000    0.003    0.000 function_base.py:257(iterable)
#      4001    0.001    0.000    0.001    0.000 function_base.py:289(_average_dispatcher)
#      4001    0.016    0.000    0.153    0.000 function_base.py:293(average)
#         2    0.000    0.000    0.000    0.000 function_base.py:4636(_append_dispatcher)
#         2    0.000    0.000    0.000    0.000 function_base.py:4640(append)
#    570213    0.124    0.000    0.294    0.000 generic.py:10(_check)
#      5001    0.013    0.000    0.049    0.000 generic.py:10579(ewm)
#     30012    0.053    0.000    0.053    0.000 generic.py:195(__init__)
#     15006    0.004    0.000    0.004    0.000 generic.py:232(attrs)
#      5004    0.005    0.000    0.012    0.000 generic.py:3180(_set_as_cached)
#         7    0.000    0.000    0.000    0.000 generic.py:3250(_clear_item_cache)
#      5001    0.012    0.000    0.020    0.000 generic.py:334(_construct_axes_from_arguments)
#     23001    0.025    0.000    0.346    0.000 generic.py:3534(_get_item_cache)
#         1    0.000    0.000    0.000    0.000 generic.py:3553(_slice)
#         3    0.000    0.000    0.000    0.000 generic.py:3570(_iset_item)
#         4    0.000    0.000    0.001    0.000 generic.py:3574(_set_item)
#         1    0.000    0.000    0.000    0.000 generic.py:3584(_set_is_copy)
#         4    0.000    0.000    0.000    0.000 generic.py:3611(_check_setitem_copy)
#      5001    0.004    0.000    0.005    0.000 generic.py:362(<dictcomp>)
#     45010    0.020    0.000    0.020    0.000 generic.py:365(_get_axis_number)
#     10002    0.005    0.000    0.015    0.000 generic.py:372(_get_axis_name)
#     10002    0.009    0.000    0.011    0.000 generic.py:377(_get_axis)
#     15004    0.010    0.000    0.013    0.000 generic.py:382(_get_block_manager_axis)
#      5001    0.032    0.000    1.179    0.000 generic.py:4216(reindex)
#     10002    0.010    0.000    0.473    0.000 generic.py:4450(<genexpr>)
#         5    0.000    0.000    0.000    0.000 generic.py:447(_info_axis)
#      5001    0.008    0.000    0.020    0.000 generic.py:4492(_needs_reindex_multi)
#      5001    0.025    0.000    0.160    0.000 generic.py:4504(_reindex_with_indexers)
#     20004    0.009    0.000    0.016    0.000 generic.py:471(ndim)
#     20007    0.017    0.000    0.023    0.000 generic.py:5097(__finalize__)
#      5004    0.006    0.000    0.006    0.000 generic.py:5125(__getattr__)
#     30018    0.036    0.000    0.058    0.000 generic.py:5143(__setattr__)
#     15003    0.016    0.000    0.090    0.000 generic.py:5199(_protect_consolidate)
#     15003    0.009    0.000    0.099    0.000 generic.py:5210(_consolidate_inplace)
#     15003    0.018    0.000    0.071    0.000 generic.py:5213(f)
#      5001    0.006    0.000    0.032    0.000 generic.py:5218(_consolidate)
#      5001    0.006    0.000    0.083    0.000 generic.py:5270(values)
#      5001    0.010    0.000    0.494    0.000 generic.py:5383(_to_dict_of_blocks)
#      5001    0.011    0.000    0.037    0.000 generic.py:5390(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 generic.py:5560(copy)
#         2    0.000    0.000    0.000    0.000 generic.py:562(_set_axis)
#         1    0.000    0.000    0.000    0.000 index_tricks.py:318(__getitem__)
#      5001    0.030    0.000    0.179    0.000 index_tricks.py:636(__init__)
#      5001    0.001    0.000    0.001    0.000 index_tricks.py:644(__iter__)
#     10002    0.007    0.000    0.010    0.000 index_tricks.py:655(__next__)
#         5    0.000    0.000    0.000    0.000 indexing.py:2126(convert_to_index_sliceable)
#     63024    0.023    0.000    0.032    0.000 inference.py:322(is_hashable)
#         4    0.000    0.000    0.000    0.000 inference.py:360(is_sequence)
#      5001    0.011    0.000    2.726    0.001 inference.py:391(is_dataclass)
#       551    0.002    0.000    0.062    0.000 iostream.py:197(schedule)
#       139    0.000    0.000    0.000    0.000 iostream.py:309(_is_master_process)
#       139    0.000    0.000    0.012    0.000 iostream.py:322(_schedule_flush)
#       137    0.001    0.000    0.059    0.000 iostream.py:336(flush)
#       139    0.001    0.000    0.036    0.000 iostream.py:384(write)
#       551    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#      6000    0.007    0.000    0.010    0.000 locale.py:379(normalize)
#      6000    0.004    0.000    0.014    0.000 locale.py:462(_parse_localename)
#      6000    0.005    0.000    0.031    0.000 locale.py:565(getlocale)
#         3    0.000    0.000    0.000    0.000 managers.py:1052(iset)
#         3    0.000    0.000    0.000    0.000 managers.py:1080(value_getitem)
#         1    0.000    0.000    0.000    0.000 managers.py:1171(insert)
#      5001    0.008    0.000    0.097    0.000 managers.py:1247(reindex_indexer)
#     25008    0.050    0.000    0.252    0.000 managers.py:132(__init__)
#     25008    0.023    0.000    0.043    0.000 managers.py:138(<listcomp>)
#      5004    0.007    0.000    0.008    0.000 managers.py:1541(__init__)
#     10004    0.008    0.000    0.045    0.000 managers.py:156(from_blocks)
#     33003    0.007    0.000    0.007    0.000 managers.py:1584(_block)
#     33003    0.020    0.000    0.032    0.000 managers.py:1622(internal_values)
#      5008    0.004    0.000    0.144    0.000 managers.py:163(blknos)
#     10002    0.034    0.000    0.581    0.000 managers.py:1660(create_block_manager_from_blocks)
#      5008    0.001    0.000    0.001    0.000 managers.py:179(blklocs)
#         1    0.000    0.000    0.000    0.000 managers.py:2017(_fast_count_smallints)
#     35012    0.047    0.000    0.137    0.000 managers.py:212(shape)
#    105036    0.025    0.000    0.090    0.000 managers.py:214(<genexpr>)
#     45037    0.013    0.000    0.017    0.000 managers.py:216(ndim)
#         2    0.000    0.000    0.000    0.000 managers.py:220(set_axis)
#     10002    0.003    0.000    0.004    0.000 managers.py:233(_is_single_block)
#      5002    0.057    0.000    0.141    0.000 managers.py:238(_rebuild_blknos_and_blklocs)
#     25007    0.005    0.000    0.005    0.000 managers.py:259(items)
#      5001    0.003    0.000    0.008    0.000 managers.py:309(__len__)
#     15003    0.040    0.000    0.150    0.000 managers.py:324(_verify_integrity)
#     30006    0.011    0.000    0.016    0.000 managers.py:326(<genexpr>)
#      5003    0.019    0.000    0.082    0.000 managers.py:369(apply)
#      5003    0.001    0.000    0.001    0.000 managers.py:388(<dictcomp>)
#     30006    0.014    0.000    0.066    0.000 managers.py:684(is_consolidated)
#     20004    0.031    0.000    0.053    0.000 managers.py:692(_consolidate_check)
#     20004    0.012    0.000    0.018    0.000 managers.py:693(<listcomp>)
#      5001    0.045    0.000    0.335    0.000 managers.py:746(_combine)
#      5001    0.013    0.000    0.014    0.000 managers.py:752(<listcomp>)
#         1    0.000    0.000    0.000    0.000 managers.py:766(get_slice)
#         1    0.000    0.000    0.000    0.000 managers.py:772(<listcomp>)
#      5003    0.008    0.000    0.090    0.000 managers.py:786(copy)
#         4    0.000    0.000    0.000    0.000 managers.py:804(copy_func)
#         2    0.000    0.000    0.000    0.000 managers.py:807(<listcomp>)
#      5001    0.014    0.000    0.038    0.000 managers.py:815(as_array)
#      5001    0.034    0.000    0.446    0.000 managers.py:910(to_dict)
#      5001    0.009    0.000    0.344    0.000 managers.py:933(<dictcomp>)
#     15003    0.006    0.000    0.040    0.000 managers.py:970(consolidate)
#     15003    0.006    0.000    0.039    0.000 managers.py:986(_consolidate_inplace)
#      5004    0.023    0.000    0.209    0.000 managers.py:993(iget)
#     10002    0.050    0.000    0.695    0.000 missing.py:358(array_equivalent)
#      5001    0.003    0.000    0.004    0.000 missing.py:665(clean_reindex_fill_method)
#      5001    0.001    0.000    0.001    0.000 missing.py:75(clean_fill_method)
#     10006    0.002    0.000    0.002    0.000 multiarray.py:1043(copyto)
#     14007    0.003    0.000    0.003    0.000 multiarray.py:145(concatenate)
#      4001    0.001    0.000    0.001    0.000 multiarray.py:635(result_type)
#      4001    0.001    0.000    0.001    0.000 multiarray.py:707(dot)
#      5001    0.001    0.000    0.001    0.000 multiarray.py:77(empty_like)
#         1    0.000    0.000    0.000    0.000 multiarray.py:853(bincount)
#      5004    0.001    0.000    0.001    0.000 numeric.py:150(is_all_dates)
#     10002    0.002    0.000    0.002    0.000 numeric.py:2283(_array_equal_dispatcher)
#     10002    0.035    0.000    0.090    0.000 numeric.py:2287(array_equal)
#     18002    0.002    0.000    0.002    0.000 numeric.py:237(inferred_type)
#      5005    0.011    0.000    0.040    0.000 numeric.py:283(full)
#      5001    0.016    0.000    0.052    0.000 numeric.py:50(__new__)
#     25007    0.004    0.000    0.004    0.000 numeric.py:81(_validate_dtype)
#      5001    0.001    0.000    0.001    0.000 numeric.py:86(_zeros_like_dispatcher)
#      5001    0.011    0.000    0.054    0.000 numeric.py:90(zeros_like)
#     10002    0.006    0.000    0.010    0.000 numerictypes.py:293(issubclass_)
#      5001    0.007    0.000    0.018    0.000 numerictypes.py:365(issubdtype)
#      8004    0.043    0.000    0.055    0.000 numerictypes.py:578(_can_coerce_all)
#     56024    0.009    0.000    0.009    0.000 numerictypes.py:587(<listcomp>)
#      4002    0.008    0.000    0.068    0.000 numerictypes.py:602(find_common_type)
#      4002    0.004    0.000    0.004    0.000 numerictypes.py:654(<listcomp>)
#      4002    0.001    0.000    0.001    0.000 numerictypes.py:655(<listcomp>)
#         1    0.000    0.000    0.000    0.000 process.py:35(current_process)
#         8    0.000    0.000    0.000    0.000 random.py:223(_randbelow)
#         8    0.000    0.000    0.000    0.000 random.py:255(choice)
#         1    0.000    0.000    0.000    0.000 random.py:87(__init__)
#         1    0.000    0.000    0.000    0.000 random.py:96(seed)
#      5001    0.005    0.000    0.036    0.000 range.py:116(from_range)
#     15008    0.029    0.000    0.090    0.000 range.py:134(_simple_new)
#     15003    0.016    0.000    0.031    0.000 range.py:153(_data)
#      5001    0.003    0.000    0.003    0.000 range.py:214(start)
#      5001    0.001    0.000    0.001    0.000 range.py:237(stop)
#      5001    0.001    0.000    0.001    0.000 range.py:260(step)
#     10002    0.007    0.000    0.007    0.000 range.py:320(dtype)
#      5001    0.001    0.000    0.001    0.000 range.py:324(is_unique)
#      5001    0.009    0.000    0.015    0.000 range.py:341(__contains__)
#     23001    0.019    0.000    0.029    0.000 range.py:349(get_loc)
#      5003    0.007    0.000    0.022    0.000 range.py:393(_shallow_copy)
#      5001    0.007    0.000    0.045    0.000 range.py:404(copy)
#      5001    0.003    0.000    0.003    0.000 range.py:452(equals)
#     80040    0.031    0.000    0.040    0.000 range.py:687(__len__)
#      5002    0.009    0.000    0.011    0.000 range.py:697(__getitem__)
#     10004    0.038    0.000    0.160    0.000 range.py:86(__new__)
#         3    0.000    0.000    0.001    0.000 re.py:231(compile)
#         3    0.000    0.000    0.001    0.000 re.py:286(_compile)
#         2    0.000    0.000    0.000    0.000 re.py:324(_subx)
#      5001    0.008    0.000    0.502    0.000 rolling.py:222(_create_blocks)
#      5001    0.006    0.000    0.006    0.000 rolling.py:256(__getattr__)
#      5001    0.029    0.000    0.074    0.000 rolling.py:337(_prep_values)
#      5001    0.013    0.000    0.454    0.000 rolling.py:366(_wrap_result)
#      5001    0.041    0.000    2.819    0.001 rolling.py:384(_wrap_results)
#      5001    0.002    0.000    0.004    0.000 rolling.py:450(_get_roll_func)
#      5004    0.012    0.000    0.062    0.000 series.py:201(__init__)
#      5004    0.005    0.000    0.006    0.000 series.py:398(_set_axis)
#      5004    0.010    0.000    0.015    0.000 series.py:442(name)
#      5004    0.004    0.000    0.007    0.000 series.py:492(name)
#     33003    0.013    0.000    0.046    0.000 series.py:540(_values)
#      5001    0.002    0.000    0.012    0.000 series.py:595(__len__)
#     18000    0.039    0.000    0.152    0.000 series.py:868(__getitem__)
#     18000    0.018    0.000    0.080    0.000 series.py:973(_get_value)
#      4001    0.001    0.000    0.001    0.000 shape_base.py:21(_atleast_1d_dispatcher)
#      4001    0.011    0.000    0.026    0.000 shape_base.py:25(atleast_1d)
#      5001    0.001    0.000    0.001    0.000 shape_base.py:265(_apply_along_axis_dispatcher)
#      5001    0.192    0.000    0.450    0.000 shape_base.py:269(apply_along_axis)
#     10002    0.008    0.000    0.018    0.000 shape_base.py:372(<genexpr>)
#         4    0.000    0.000    0.000    0.000 shape_base.py:79(_atleast_2d_dispatcher)
#         4    0.000    0.000    0.000    0.000 shape_base.py:83(atleast_2d)
#      5001    0.002    0.000    0.002    0.000 six.py:184(find_module)
#       551    0.059    0.000    0.059    0.000 socket.py:342(send)
#        72    0.000    0.000    0.000    0.000 sre_compile.py:102(fixup)
#        25    0.000    0.000    0.000    0.000 sre_compile.py:223(_compile_charset)
#        25    0.000    0.000    0.000    0.000 sre_compile.py:250(_optimize_charset)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:388(_simple)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:482(_compile_info)
#         2    0.000    0.000    0.000    0.000 sre_compile.py:539(isstring)
#         1    0.000    0.000    0.001    0.001 sre_compile.py:542(_code)
#         1    0.000    0.000    0.001    0.001 sre_compile.py:557(compile)
#      24/1    0.000    0.000    0.001    0.001 sre_compile.py:64(_compile)
#        24    0.000    0.000    0.000    0.000 sre_parse.py:111(__init__)
#        18    0.000    0.000    0.000    0.000 sre_parse.py:159(__len__)
#        74    0.000    0.000    0.000    0.000 sre_parse.py:163(__getitem__)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:167(__setitem__)
#        45    0.000    0.000    0.000    0.000 sre_parse.py:171(append)
#      31/8    0.000    0.000    0.000    0.000 sre_parse.py:173(getwidth)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:223(__init__)
#       141    0.000    0.000    0.000    0.000 sre_parse.py:232(__next)
#        63    0.000    0.000    0.000    0.000 sre_parse.py:248(match)
#        86    0.000    0.000    0.000    0.000 sre_parse.py:253(get)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:266(getuntil)
#        27    0.000    0.000    0.000    0.000 sre_parse.py:285(tell)
#        12    0.000    0.000    0.000    0.000 sre_parse.py:342(_escape)
#       7/1    0.000    0.000    0.000    0.000 sre_parse.py:407(_parse_sub)
#      18/1    0.000    0.000    0.000    0.000 sre_parse.py:470(_parse)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:76(__init__)
#        14    0.000    0.000    0.000    0.000 sre_parse.py:81(groups)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:828(fix_flags)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:84(opengroup)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:844(parse)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:96(closegroup)
#         1    0.000    0.000    0.000    0.000 std.py:100(<listcomp>)
#       140    0.000    0.000    0.001    0.000 std.py:104(acquire)
#       140    0.000    0.000    0.001    0.000 std.py:108(release)
#         4    0.000    0.000    0.000    0.000 std.py:112(__enter__)
#       137    0.001    0.000    0.017    0.000 std.py:1136(__repr__)
#         2    0.000    0.000    0.000    0.000 std.py:1139(_comparable)
#         2    0.000    0.000    0.000    0.000 std.py:1143(__hash__)
#      6001    0.006    0.000    0.125    0.000 std.py:1146(__iter__)
#         4    0.000    0.000    0.000    0.000 std.py:115(__exit__)
#         1    0.000    0.000    0.001    0.001 std.py:118(create_mp_lock)
#       135    0.001    0.000    0.118    0.001 std.py:1182(update)
#         1    0.000    0.000    0.001    0.001 std.py:1248(close)
#         2    0.000    0.000    0.000    0.000 std.py:1265(fp_write)
#         1    0.000    0.000    0.000    0.000 std.py:1280(<lambda>)
#       136    0.000    0.000    0.118    0.001 std.py:1304(refresh)
#       137    0.001    0.000    0.001    0.000 std.py:1420(format_dict)
#       137    0.000    0.000    0.117    0.001 std.py:1436(display)
#       137    0.000    0.000    0.000    0.000 std.py:155(__init__)
#       137    0.000    0.000    0.000    0.000 std.py:165(colour)
#       137    0.000    0.000    0.000    0.000 std.py:169(colour)
#       137    0.001    0.000    0.001    0.000 std.py:188(__format__)
#         3    0.000    0.000    0.000    0.000 std.py:229(__init__)
#       811    0.001    0.000    0.001    0.000 std.py:234(__call__)
#       273    0.000    0.000    0.001    0.000 std.py:289(format_interval)
#         1    0.000    0.000    0.000    0.000 std.py:330(status_printer)
#       137    0.000    0.000    0.095    0.001 std.py:340(fp_write)
#       137    0.000    0.000    0.099    0.001 std.py:346(print_status)
#       137    0.003    0.000    0.016    0.000 std.py:353(format_meter)
#         1    0.000    0.000    0.001    0.001 std.py:560(__new__)
#         1    0.000    0.000    0.000    0.000 std.py:576(_get_free_pos)
#         1    0.000    0.000    0.000    0.000 std.py:579(<setcomp>)
#         1    0.000    0.000    0.000    0.000 std.py:583(_decr_instances)
#         1    0.000    0.000    0.001    0.001 std.py:657(get_lock)
#         1    0.000    0.000    0.002    0.002 std.py:838(__init__)
#         1    0.000    0.000    0.001    0.001 std.py:92(__init__)
#      4001    0.034    0.000    0.049    0.000 stride_tricks.py:116(_broadcast_to)
#      8002    0.002    0.000    0.002    0.000 stride_tricks.py:121(<genexpr>)
#      4001    0.001    0.000    0.001    0.000 stride_tricks.py:139(_broadcast_to_dispatcher)
#      4001    0.003    0.000    0.052    0.000 stride_tricks.py:143(broadcast_to)
#      5001    0.002    0.000    0.002    0.000 stride_tricks.py:21(__init__)
#      9002    0.004    0.000    0.004    0.000 stride_tricks.py:26(_maybe_view_as_subclass)
#      5001    0.048    0.000    0.078    0.000 stride_tricks.py:39(as_strided)
#         1    0.000    0.000    0.000    0.000 synchronize.py:11(<module>)
#         1    0.000    0.000    0.000    0.000 synchronize.py:115(_make_name)
#         1    0.000    0.000    0.000    0.000 synchronize.py:124(Semaphore)
#         1    0.000    0.000    0.000    0.000 synchronize.py:143(BoundedSemaphore)
#         1    0.000    0.000    0.000    0.000 synchronize.py:160(Lock)
#         1    0.000    0.000    0.000    0.000 synchronize.py:185(RLock)
# ...
#         1    0.000    0.000    0.000    0.000 synchronize.py:47(SemLock)
#         1    0.000    0.000    0.000    0.000 synchronize.py:51(__init__)
#         1    0.000    0.000    0.000    0.000 synchronize.py:91(_make_methods)
#         1    0.000    0.000    0.000    0.000 tempfile.py:146(rng)
#         1    0.000    0.000    0.000    0.000 tempfile.py:157(__next__)
#         1    0.000    0.000    0.000    0.000 tempfile.py:160(<listcomp>)
#       688    0.000    0.000    0.001    0.000 threading.py:1062(_wait_for_tstate_lock)
#       688    0.001    0.000    0.002    0.000 threading.py:1104(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:1120(daemon)
#         1    0.000    0.000    0.000    0.000 threading.py:1136(daemon)
#         1    0.000    0.000    0.000    0.000 threading.py:1230(current_thread)
#       139    0.001    0.000    0.001    0.000 threading.py:215(__init__)
#       138    0.000    0.000    0.000    0.000 threading.py:239(__enter__)
#       138    0.000    0.000    0.000    0.000 threading.py:242(__exit__)
#       138    0.000    0.000    0.000    0.000 threading.py:248(_release_save)
#       138    0.000    0.000    0.000    0.000 threading.py:251(_acquire_restore)
#       138    0.000    0.000    0.000    0.000 threading.py:254(_is_owned)
#       138    0.001    0.000    0.026    0.000 threading.py:263(wait)
#       139    0.000    0.000    0.001    0.000 threading.py:498(__init__)
#       690    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#       138    0.001    0.000    0.027    0.000 threading.py:533(wait)
#         1    0.000    0.000    0.000    0.000 threading.py:727(_newname)
#         1    0.000    0.000    0.000    0.000 threading.py:757(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:828(start)
#       138    0.000    0.000    0.000    0.000 typing.py:1019(_abc_negative_cache)
#        79    0.000    0.000    0.000    0.000 typing.py:1033(_abc_negative_cache_version)
#       313    0.000    0.000    0.000    0.000 typing.py:1089(__eq__)
#   815/129    0.000    0.000    0.002    0.000 typing.py:1145(__subclasscheck__)
#     21/20    0.000    0.000    0.000    0.000 typing.py:875(__extrahook__)
#        38    0.000    0.000    0.000    0.000 typing.py:889(__extrahook__)
#         1    0.000    0.000    0.000    0.000 util.py:48(debug)
#         3    0.000    0.000    0.000    0.000 utils.py:101(wrapper_setattr)
#         1    0.000    0.000    0.000    0.000 utils.py:105(__init__)
#         2    0.000    0.000    0.000    0.000 utils.py:136(disable_on_exception)
#       276    0.001    0.000    0.095    0.000 utils.py:141(inner)
#         1    0.000    0.000    0.000    0.000 utils.py:154(__init__)
#         3    0.000    0.000    0.000    0.000 utils.py:163(__eq__)
#         1    0.000    0.000    0.000    0.000 utils.py:193(_is_utf)
#         1    0.000    0.000    0.000    0.000 utils.py:207(_supports_unicode)
#       274    0.001    0.000    0.001    0.000 utils.py:214(_is_ascii)
#         1    0.000    0.000    0.000    0.000 utils.py:223(_screen_shape_wrapper)
#         1    0.000    0.000    0.000    0.000 utils.py:238(_screen_shape_windows)
#       411    0.000    0.000    0.010    0.000 utils.py:320(_text_width)
#     28349    0.005    0.000    0.008    0.000 utils.py:321(<genexpr>)
#       411    0.000    0.000    0.011    0.000 utils.py:324(disp_len)
#       137    0.000    0.000    0.004    0.000 utils.py:332(disp_trim)
#       137    0.000    0.000    0.000    0.000 utils.py:57(__init__)
#       137    0.000    0.000    0.000    0.000 utils.py:61(__format__)
#         1    0.000    0.000    0.000    0.000 utils.py:74(__eq__)
#         1    0.000    0.000    0.000    0.000 utils.py:88(__getattr__)
#     29023    0.010    0.000    0.010    0.000 {built-in method __new__ of type object at 0x0000000068C6C3F0}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#     30011    0.004    0.000    0.004    0.000 {built-in method _imp.acquire_lock}
#      5001    0.006    0.000    0.006    0.000 {built-in method _imp.is_builtin}
#      5002    0.002    0.000    0.002    0.000 {built-in method _imp.is_frozen}
#       137    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#     30011    0.004    0.000    0.004    0.000 {built-in method _imp.release_lock}
#      6000    0.012    0.000    0.012    0.000 {built-in method _locale.setlocale}
#         1    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#        81    0.000    0.000    0.000    0.000 {built-in method _sre.getlower}
#         1    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#     10281    0.021    0.000    0.021    0.000 {built-in method _thread.allocate_lock}
#     10005    0.002    0.000    0.002    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#       139    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
# 20007/15006    0.009    0.000    0.480    0.000 {built-in method builtins.all}
#     14004    0.009    0.000    0.030    0.000 {built-in method builtins.any}
#     46022    0.005    0.000    0.005    0.000 {built-in method builtins.callable}
#       683    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#       2/1    0.000    0.000   19.041   19.041 {built-in method builtins.exec}
#    898495    0.266    0.000    0.268    0.000 {built-in method builtins.getattr}
#    193362    0.054    0.000    0.055    0.000 {built-in method builtins.hasattr}
#     86034    0.011    0.000    0.011    0.000 {built-in method builtins.hash}
#     10004    0.001    0.000    0.001    0.000 {built-in method builtins.id}
# 1568136/1567995    0.321    0.000    0.643    0.000 {built-in method builtins.isinstance}
# 255112/254167    0.038    0.000    0.040    0.000 {built-in method builtins.issubclass}
#      4005    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
# 690840/570772    0.116    0.000    0.162    0.000 {built-in method builtins.len}
#      5291    0.003    0.000    0.003    0.000 {built-in method builtins.max}
#        66    0.000    0.000    0.000    0.000 {built-in method builtins.min}
# 15004/10003    0.005    0.000    0.014    0.000 {built-in method builtins.next}
#      2912    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#      5001    0.005    0.000    0.005    0.000 {built-in method builtins.sorted}
#     31415    0.024    0.000    0.054    0.000 {built-in method builtins.sum}
#         2    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         1    0.000    0.000    0.000    0.000 {built-in method marshal.loads}
#      4001    0.002    0.000    0.002    0.000 {built-in method math.atan}
#      4001    0.001    0.000    0.001    0.000 {built-in method math.degrees}
#       136    0.000    0.000    0.000    0.000 {built-in method now}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#      5001    0.005    0.000    0.005    0.000 {built-in method nt.getcwd}
#       140    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method nt.listdir}
#     55014    1.637    0.000    1.637    0.000 {built-in method nt.stat}
#     10009    0.019    0.000    0.019    0.000 {built-in method numpy.arange}
# 192070/192069    1.320    0.000    1.320    0.000 {built-in method numpy.array}
#     12003    0.015    0.000    0.015    0.000 {built-in method numpy.core._multiarray_umath._insert}
# 164057/83034    0.231    0.000    2.144    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      5001    0.002    0.000    0.002    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#     20015    0.071    0.000    0.071    0.000 {built-in method numpy.empty}
#     19004    0.025    0.000    0.025    0.000 {built-in method numpy.zeros}
#      6000    0.007    0.000    0.154    0.000 {built-in method strptime}
#       736    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#      1370    0.000    0.000    0.000    0.000 {built-in method time.time}
#     27938    0.003    0.000    0.003    0.000 {built-in method unicodedata.east_asian_width}
#         1    0.000    0.000    0.000    0.000 {built-in method utcfromtimestamp}
#         1    0.000    0.000    0.000    0.000 {function Random.seed at 0x000001F4A06F9268}
#      5001    0.001    0.000    0.001    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#      5001    0.001    0.000    0.001    0.000 {method '__array_wrap__' of 'numpy.ndarray' objects}
#       138    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#       138    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#       145    0.000    0.000    0.000    0.000 {method '__subclasses__' of 'type' objects}
#       140    0.000    0.000    0.000    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       141    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#      1240    0.026    0.000    0.026    0.000 {method 'acquire' of '_thread.lock' objects}
#     15266    0.002    0.000    0.002    0.000 {method 'add' of 'set' objects}
#     10002    0.006    0.000    0.041    0.000 {method 'all' of 'numpy.ndarray' objects}
#      4001    0.006    0.000    0.020    0.000 {method 'any' of 'numpy.generic' objects}
#     10003    0.008    0.000    0.051    0.000 {method 'any' of 'numpy.ndarray' objects}
#     13690    0.002    0.000    0.002    0.000 {method 'append' of 'collections.deque' objects}
#   8066420    0.377    0.000    0.377    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         8    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         7    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#      4001    0.001    0.000    0.001    0.000 {method 'conj' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#     14021    0.024    0.000    0.024    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#      6000    0.001    0.000    0.001    0.000 {method 'end' of '_sre.SRE_Match' objects}
#         1    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#     10004    0.005    0.000    0.005    0.000 {method 'fill' of 'numpy.ndarray' objects}
#        51    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#     11101    0.010    0.000    0.010    0.000 {method 'format' of 'str' objects}
#     51025    0.010    0.000    0.010    0.000 {method 'get' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#        10    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#      6000    0.008    0.000    0.008    0.000 {method 'groupdict' of '_sre.SRE_Match' objects}
#     23001    0.008    0.000    0.008    0.000 {method 'index' of 'range' objects}
#         6    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#     29007    0.004    0.000    0.004    0.000 {method 'items' of 'dict' objects}
#    275063    0.038    0.000    0.038    0.000 {method 'join' of 'str' objects}
#     11001    0.001    0.000    0.001    0.000 {method 'keys' of 'dict' objects}
#      6015    0.001    0.000    0.001    0.000 {method 'lower' of 'str' objects}
#      6000    0.013    0.000    0.013    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#      4001    0.003    0.000    0.067    0.000 {method 'mean' of 'numpy.ndarray' objects}
#      8003    0.006    0.000    0.006    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         9    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#     55011    0.007    0.000    0.007    0.000 {method 'pop' of 'dict' objects}
#      5001    0.003    0.000    0.003    0.000 {method 'pop' of 'list' objects}
#      5999    0.001    0.000    0.001    0.000 {method 'popleft' of 'collections.deque' objects}
#     16006    0.009    0.000    0.009    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'read' of '_io.FileIO' objects}
#     36009    0.143    0.000    0.143    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       140    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#       141    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#       138    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#       128    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#     13003    0.016    0.000    0.016    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      4001    0.254    0.000    0.254    0.000 {method 'round' of 'numpy.ndarray' objects}
#     60022    0.008    0.000    0.008    0.000 {method 'rpartition' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'rsplit' of 'str' objects}
#    550122    0.059    0.000    0.059    0.000 {method 'rstrip' of 'str' objects}
#      5001    0.002    0.000    0.002    0.000 {method 'setdefault' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'setter' of 'property' objects}
#      5001    0.005    0.000    0.005    0.000 {method 'sort' of 'numpy.ndarray' objects}
#      6000    0.003    0.000    0.003    0.000 {method 'split' of 'str' objects}
#      4001    0.001    0.000    0.001    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#      5005    0.002    0.000    0.002    0.000 {method 'startswith' of 'str' objects}
#       413    0.000    0.000    0.000    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#     13003    0.018    0.000    0.018    0.000 {method 'take' of 'numpy.ndarray' objects}
#     12000    0.002    0.000    0.002    0.000 {method 'toordinal' of 'datetime.date' objects}
#     15005    0.011    0.000    0.011    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#      5138    0.002    0.000    0.002    0.000 {method 'update' of 'dict' objects}
#      5001    0.001    0.000    0.001    0.000 {method 'upper' of 'str' objects}
#     10002    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}
#      6000    0.001    0.000    0.001    0.000 {method 'weekday' of 'datetime.date' objects}
#      5001    0.002    0.000    0.002    0.000 {pandas._libs.algos.ensure_float64}
#      5001    0.001    0.000    0.001    0.000 {pandas._libs.algos.ensure_platform_int}
#         3    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#      5001    0.032    0.000    0.032    0.000 {pandas._libs.lib.get_reverse_indexer}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#      5003    0.001    0.000    0.001    0.000 {pandas._libs.lib.is_bool}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#     64007    0.007    0.000    0.007    0.000 {pandas._libs.lib.is_integer}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#     10003    0.010    0.000    0.033    0.000 {pandas._libs.lib.is_list_like}
#     43013    0.006    0.000    0.006    0.000 {pandas._libs.lib.is_scalar}
#     23002    0.004    0.000    0.004    0.000 {pandas._libs.lib.item_from_zerodim}
#      5005    0.941    0.000    0.981    0.000 {pandas._libs.lib.maybe_convert_objects}
#
#
# Wall time: 24.1 s

# %%
print(data['total_df'].groupby(['date_val'])['pls'].sum())

# %%
data['total_df']['pls'].value_counts()

# %%
winsound.PlaySound('C:\\Windows\\Media\\chimes.wav', winsound.SND_ASYNC)
