# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *
import winsound

# %%
data["plot"] = True

data['pl_move_trail_trigger']   = 0.0030
data['stop_loss_pip']           = 0.0020

data['input_rows'] = 10000

data['sema_len']        = 30
data['slema_len']       = 100
data['lema_len']        = 300
data['llema_len']       = 1000

data['start_date'] = {'year':2021, 'month':1, 'date':1}
data['end_date']   = {'year':2021, 'month':1, 'date':4}

# %%
# %%time
data = get_date_list(data)
data = read_data(data)
data = run_engine(data)
# Out:
#  94%|██████████████████████████████████  | 9447/10000 [00:48<00:03, 162.70it/s]
# pls   -0.00094
# dtype: float64
# --------------------------------------
#                   date ord_types  llema_angle               close_type  \
# 3  2021-01-03 23:29:04      long           14  simple_slema_move_close
# 4  2021-01-03 23:42:48      long           37  simple_slema_move_close
# 5  2021-01-03 23:48:35      long           14  simple_slema_move_close
# 6  2021-01-03 23:53:31      long           34  simple_slema_move_close
# 7  2021-01-03 23:59:23      long           13  simple_slema_move_close
# 8  2021-01-04 00:01:25      long           15               sema_close
# 9  2021-01-04 00:03:01     short           -6  simple_slema_move_close
# 10 2021-01-04 00:17:14     short          -37  simple_slema_move_close
# 11 2021-01-04 00:22:27     short          -20  simple_slema_move_close
# 12 2021-01-04 00:34:54      long           15               sema_close
# 13 2021-01-04 00:39:29     short          -18  simple_slema_move_close
# 14 2021-01-04 00:49:33     short          -23               sema_close
# 15 2021-01-04 00:49:55      long            6               sema_close
# 16 2021-01-04 00:50:48     short           -6               sema_close
# 17 2021-01-04 00:59:19      long            8               sema_close
#
#         pls
# 3   0.00001
# 4   0.00016
# 5   0.00024
# 6   0.00011
# 7   0.00002
# 8  -0.00027
# 9   0.00032
# 10  0.00001
# 11  0.00011
# 12 -0.00046
# 13  0.00007
# 14 -0.00031
# 15 -0.00013
# 16 -0.00013
# 17 -0.00026
# 100%|███████████████████████████████████| 10000/10000 [00:51<00:00, 193.73it/s]
# Wall time: 51.6 s

# %%
if data["plot"]:
    data = adjust_plot_list_lengths(data)
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['date_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df']['pls'].value_counts())
print('-----------------------------------------------------')
data['report_df']

winsound.PlaySound('C:\\Windows\\Media\\tada.wav', winsound.SND_ASYNC)
# Out:
# -----------------------------------------------------
# ==============================
# date_val          : ['20210101', '20210102', '20210103', '20210104']
# Total PL : -0.0009399999999999999
# -------------
# net_pl            : -0.00094/0.00314
# -------------
# +ve               : num= 11    sum= +0.0011    avg= +0.0001
# -ve               : num= 7    sum= -0.00204    avg= -0.00029
# ==============================
# -----------------------------------------------------
# date_val
# 3    0.00011
# 4   -0.00105
# Name: pls, dtype: float64
# -----------------------------------------------------
#  0.00001    3
#  0.00011    2
# -0.00013    2
#  0.00032    1
# -0.00031    1
#  0.00007    1
# -0.00046    1
#  0.00024    1
#  0.00002    1
#  0.00004    1
# -0.00027    1
#  0.00016    1
# -0.00026    1
# -0.00048    1
# Name: pls, dtype: int64
# -----------------------------------------------------

# %%
data['report_df'][['date', 'ord_types', 'llema_angle','close_type', 'pls']]
# Out:
#                   date ord_types  llema_angle               close_type  \
# 0  2021-01-03 23:09:09     short          -26               sema_close
# 1  2021-01-03 23:11:19      long           18  simple_slema_move_close
# 2  2021-01-03 23:15:49      long           17  simple_slema_move_close
# 3  2021-01-03 23:29:04      long           14  simple_slema_move_close
# 4  2021-01-03 23:42:48      long           37  simple_slema_move_close
# 5  2021-01-03 23:48:35      long           14  simple_slema_move_close
# 6  2021-01-03 23:53:31      long           34  simple_slema_move_close
# 7  2021-01-03 23:59:23      long           13  simple_slema_move_close
# 8  2021-01-04 00:01:25      long           15               sema_close
# 9  2021-01-04 00:03:01     short           -6  simple_slema_move_close
# 10 2021-01-04 00:17:14     short          -37  simple_slema_move_close
# 11 2021-01-04 00:22:27     short          -20  simple_slema_move_close
# 12 2021-01-04 00:34:54      long           15               sema_close
# 13 2021-01-04 00:39:29     short          -18  simple_slema_move_close
# 14 2021-01-04 00:49:33     short          -23               sema_close
# 15 2021-01-04 00:49:55      long            6               sema_close
# 16 2021-01-04 00:50:48     short           -6               sema_close
# 17 2021-01-04 00:59:19      long            8               sema_close
#
#         pls
# 0  -0.00048
# 1   0.00004
# 2   0.00001
# 3   0.00001
# 4   0.00016
# 5   0.00024
# 6   0.00011
# 7   0.00002
# 8  -0.00027
# 9   0.00032
# 10  0.00001
# 11  0.00011
# 12 -0.00046
# 13  0.00007
# 14 -0.00031
# 15 -0.00013
# 16 -0.00013
# 17 -0.00026

# %%
data['df']
# Out:
#                    DateTime      Bid      Ask  Volume  i      tick      sema  \
# 0     20210103 23:00:17.204  1.22392  1.22405       1  0  1.223985  1.224033
# 1     20210103 23:00:17.305  1.22393  1.22405       1  0  1.223990  1.224029
# 2     20210103 23:00:17.407  1.22393  1.22411       1  0  1.224020  1.224028
# 3     20210103 23:00:18.161  1.22392  1.22410       1  0  1.224010  1.224026
# 4     20210103 23:00:18.380  1.22392  1.22411       1  0  1.224015  1.224025
# ...                     ...      ...      ...     ... ..       ...       ...
# 8985  20210104 01:07:09.505  1.22450  1.22456       5  0  1.224530  1.224528
# 8986  20210104 01:07:09.862  1.22451  1.22457       2  0  1.224540  1.224529
# 8987  20210104 01:07:09.964  1.22452  1.22457       3  0  1.224545  1.224530
# 8988  20210104 01:07:10.066  1.22452  1.22458       3  0  1.224550  1.224532
# 8989  20210104 01:07:10.167  1.22454  1.22458       1  0  1.224560  1.224534
#
#           lema   ll_angle     llema     slema
# 0     1.223781  33.929797  1.223674  1.224017
# 1     1.223782  33.206570  1.223675  1.224019
# 2     1.223784  33.929797  1.223676  1.224021
# 3     1.223786  33.929797  1.223676  1.224022
# 4     1.223788  33.206570  1.223677  1.224024
# ...        ...        ...       ...       ...
# 8985  1.224344  36.027373  1.224214  1.224476
# 8986  1.224345  34.875328  1.224214  1.224478
# 8987  1.224347  35.108380  1.224215  1.224480
# 8988  1.224349  36.702855  1.224216  1.224482
# 8989  1.224351  37.146687  1.224217  1.224485
#
# [8990 rows x 11 columns]
