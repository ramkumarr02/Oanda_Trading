# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *
import winsound
from tqdm import tqdm
tqdm.pandas()

# %%
# %%time
data = get_date_list(data)
# data = read_data(data)
data = run_engine(data)
# Out:
#  98%|████████████████████████████▎| 1523125/1562097 [01:19<00:02, 16011.97it/s]
# pls   -0.01304
# dtype: float64
# --------------------------------------
#                   date ord_types               close_type      pls
# 2  2020-02-13 08:50:08     short               tick_close  0.00180
# 3  2020-02-14 21:45:24      long               sema_close -0.00245
# 4  2020-02-17 15:49:58     short  simple_slema_move_close  0.00002
# 5  2020-02-20 07:23:53      long               sema_close -0.00313
# 6  2020-02-20 14:19:56     short               sema_close -0.00297
# 7  2020-02-20 20:12:37      long               sema_close -0.00238
# 8  2020-02-21 08:37:13     short               sema_close -0.00234
# 9  2020-02-23 22:00:02      long               tick_close  0.00043
# 10 2020-02-24 15:03:52     short             reverse_stop -0.00400
# 11 2020-02-25 01:22:45      long  simple_slema_move_close  0.00001
# 12 2020-02-25 16:11:42     short               sema_close -0.00309
# 13 2020-02-26 03:03:22      long  simple_slema_move_close  0.00001
# 14 2020-02-26 17:55:45     short               sema_close -0.00214
# 15 2020-02-27 17:16:01      long               tick_close  0.00845
# 16 2020-02-28 16:05:59     short               tick_close  0.00009
# 100%|█████████████████████████████| 1562097/1562097 [01:21<00:00, 19099.90it/s]
# Wall time: 2min 22s

# %%
if data["plot"]:
    data = adjust_plot_list_lengths(data)
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['month_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df']['close_type'].value_counts())
print('-----------------------------------------------------')
data['report_df']

winsound.PlaySound('C:\\Windows\\Media\\tada.wav', winsound.SND_ASYNC)
# Out:
# -----------------------------------------------------
# ==============================
# date_val          : ['20200201', '20200202', '20200203', '20200204', '20200205', '20200206', '20200207', '20200208', '20200209', '20200210', '20200211', '20200212', '20200213', '20200214', '20200215', '20200216', '20200217', '20200218', '20200219', '20200220', '20200221', '20200222', '20200223', '20200224', '20200225', '20200226', '20200227', '20200228', '20200229']
# Total PL : -0.013040000000000003
# -------------
# net_pl            : -0.01304/0.03542
# -------------
# +ve               : num= 8    sum= +0.01119    avg= +0.0014
# -ve               : num= 9    sum= -0.02423    avg= -0.00269
# ==============================
# -----------------------------------------------------
# month_val
# 2   -0.01304
# Name: pls, dtype: float64
# -----------------------------------------------------
# sema_close                 8
# tick_close                 4
# simple_slema_move_close    4
# reverse_stop               1
# Name: close_type, dtype: int64
# -----------------------------------------------------

# %% [markdown]
# import glob
#
# for file in glob.glob("data/*.csv"):
#     if file not in ['data\\eurusd_2021.csv', 'data\\full_df.csv']:
#         df = pd.read_csv(file)
#         print('----------------------------')
#         print(f'file : {file}')
#         print(df['pls'].sum())
#         print(df.groupby(['month_val'])['pls'].sum())
#         print('----------------------------')

# %%
data['report_df'][['date', 'ord_types', 'close_type', 'pls']]
# Out:
#                   date ord_types               close_type      pls
# 0  2020-02-04 02:05:10     short  simple_slema_move_close  0.00038
# 1  2020-02-12 14:02:09      long               sema_close -0.00173
# 2  2020-02-13 08:50:08     short               tick_close  0.00180
# 3  2020-02-14 21:45:24      long               sema_close -0.00245
# 4  2020-02-17 15:49:58     short  simple_slema_move_close  0.00002
# 5  2020-02-20 07:23:53      long               sema_close -0.00313
# 6  2020-02-20 14:19:56     short               sema_close -0.00297
# 7  2020-02-20 20:12:37      long               sema_close -0.00238
# 8  2020-02-21 08:37:13     short               sema_close -0.00234
# 9  2020-02-23 22:00:02      long               tick_close  0.00043
# 10 2020-02-24 15:03:52     short             reverse_stop -0.00400
# 11 2020-02-25 01:22:45      long  simple_slema_move_close  0.00001
# 12 2020-02-25 16:11:42     short               sema_close -0.00309
# 13 2020-02-26 03:03:22      long  simple_slema_move_close  0.00001
# 14 2020-02-26 17:55:45     short               sema_close -0.00214
# 15 2020-02-27 17:16:01      long               tick_close  0.00845
# 16 2020-02-28 16:05:59     short               tick_close  0.00009
