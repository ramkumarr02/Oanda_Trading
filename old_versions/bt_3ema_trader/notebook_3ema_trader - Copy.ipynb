# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *
import winsound

# %%
data["plot"] = True

data['direction_flag'] = -1

data['sema_gap_pip'] = 0.0000
data['pl_move_trail_trigger']   = 0.0025
data['stop_loss_pip']           = 0.0015

data['sema_len']        = 20000
data['slema_len']       = 30000
data['lema_len']        = 40000

data['start_date'] = {'year':2021, 'month':5, 'date':1}
data['end_date']   = {'year':2021, 'month':5, 'date':6}

# %%
# %%time
data = get_date_list(data)
data = read_data(data)
data = run_engine(data)
# Out:
#  61%|████████████████████▉             | 132940/216187 [36:25<33:50, 41.00it/s]
# pls   -0.00101
# dtype: float64
# --------------------------------------
#                  date ord_types     close_type      pls
# 0 2021-05-04 07:08:59      long   reverse_stop -0.00150
# 1 2021-05-04 09:42:22     short  pl_move_close  0.00184
# 2 2021-05-04 15:16:09     short  pl_move_close  0.00166
# 3 2021-05-05 06:31:22      long   reverse_stop -0.00151
# 4 2021-05-05 10:36:02     short    simple_stop -0.00150
#  67%|██████████████████████▌           | 143859/216187 [40:29<20:21, 59.21it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# D:\Ram\PCAL\Data_Science\Projects\Trading\Oanda_Trading\bt_3ema_trader\utils\engine.py in run_engine(data)
#      41
#      42         if len(data['slema_list']) == data['slema_len']:
# ---> 43             data = after_slema(data)
#      44         # ----------------------------------------------------------
#      45
#
# D:\Ram\PCAL\Data_Science\Projects\Trading\Oanda_Trading\bt_3ema_trader\utils\loops.py in after_slema(data)
#      36     data['slema_list'].popleft()
#      37     data['slema_list'].append(data['tick'])
# ---> 38     data['slema'] = list(pd.DataFrame(list(data['slema_list'])).ewm(span=data['slema_len']).mean()[0])[-1]
#      39
#      40     if data["plot"]:
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     502                 data = list(data)
#     503             if len(data) > 0:
# --> 504                 if is_dataclass(data[0]):
#     505                     data = dataclasses_to_dicts(data)
#     506                 if is_list_like(data[0]) and getattr(data[0], "ndim", 1) == 1:
#
# c:\users\91989\appdata\local\programs\python\python36\lib\site-packages\pandas\core\dtypes\inference.py in is_dataclass(item)
#     418     """
#     419     try:
# --> 420         from dataclasses import is_dataclass
#     421
#     422         return is_dataclass(item) and not isinstance(item, type)
#
# c:\users\91989\appdata\local\programs\python\python36\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# c:\users\91989\appdata\local\programs\python\python36\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# c:\users\91989\appdata\local\programs\python\python36\lib\importlib\_bootstrap.py in _find_spec(name, path, target)
#
# c:\users\91989\appdata\local\programs\python\python36\lib\importlib\_bootstrap_external.py in find_spec(cls, fullname, path, target)
#
# c:\users\91989\appdata\local\programs\python\python36\lib\importlib\_bootstrap_external.py in _get_spec(cls, fullname, path, target)
#
# c:\users\91989\appdata\local\programs\python\python36\lib\importlib\_bootstrap_external.py in find_spec(self, fullname, target)
#
# c:\users\91989\appdata\local\programs\python\python36\lib\importlib\_bootstrap_external.py in _path_stat(path)
#
# KeyboardInterrupt:

# %%
if data["plot"]:
    data = adjust_plot_list_lengths(data)
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['date_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df']['pls'].value_counts())
print('-----------------------------------------------------')
data['report_df']

winsound.PlaySound('C:\\Windows\\Media\\tada.wav', winsound.SND_ASYNC)
# Out:
# -----------------------------------------------------
# ==============================
# date_val          : ['20210501', '20210502', '20210503', '20210504', '20210505', '20210506']
# Total PL : -0.00101
# -------------
# net_pl            : -0.00101/0.00801
# -------------
# +ve               : num= 2    sum= +0.0035    avg= +0.00175
# -ve               : num= 3    sum= -0.00451    avg= -0.0015
# ==============================
# -----------------------------------------------------
# date_val
# 4    0.00200
# 5   -0.00301
# Name: pls, dtype: float64
# -----------------------------------------------------
# -0.00150    2
# -0.00151    1
#  0.00166    1
#  0.00184    1
# Name: pls, dtype: int64
# -----------------------------------------------------
