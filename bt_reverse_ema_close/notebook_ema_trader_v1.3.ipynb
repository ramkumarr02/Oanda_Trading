# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *
import winsound

# %%
data['pl_move_flag'] = True
data['stop_loss_flag']  = True
# data['tick_close_flag'] = True

# %%
data['sema_len']        = 1000
data['lema_len']        = 10000

data['angle_len']       = 200
data['tick_angle_len']  = 400

# %%
# %%time
data = get_date_list(data)
data = read_data(data)
data = run_engine(data)

if data["plot"]:
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['date_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df']['pls'].value_counts())
print('-----------------------------------------------------')
data['report_df']

winsound.PlaySound('C:\\Windows\\Media\\tada.wav', winsound.SND_ASYNC)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍| 94686/95028 [07:38<00:02, 149.95it/s]
# pls    0.00117
# dtype: float64
# --------------------------------------
#                   date order_type order_methods     close_type      pls
# 0  2021-04-01 09:08:05      short          make  pl_move_close  0.00028
# 1  2021-04-01 11:31:41       long          make  pl_move_close  0.00002
# 2  2021-04-01 12:57:22      short          make      stop_loss -0.00030
# 3  2021-04-01 14:00:33      short          make  pl_move_close  0.00006
# 4  2021-04-01 14:16:39      short          make    angle_close  0.00069
# 5  2021-04-01 15:02:16       long          make    angle_close  0.00087
# 6  2021-04-01 20:27:59       long          make  pl_move_close  0.00005
# 7  2021-04-02 04:14:55       long          make  pl_move_close  0.00030
# 8  2021-04-02 05:18:44      short          make      stop_loss -0.00030
# 9  2021-04-02 06:27:12      short          make      stop_loss -0.00032
# 10 2021-04-02 11:19:45      short          make  pl_move_close  0.00006
# 11 2021-04-04 23:10:25      short          make  pl_move_close  0.00006
# 12 2021-04-04 23:30:43      short          make      stop_loss -0.00030
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 95028/95028 [07:41<00:00, 206.13it/s]
# -----------------------------------------------------
# ==============================
# date_val          : ['20210401', '20210402', '20210403', '20210404']
# Total PL : 0.00117
# -------------
# net_pl            : 0.00117/0.00361
# -------------
# +ve               : num= 9    sum= +0.00239    avg= +0.00027
# -ve               : num= 4    sum= -0.00122    avg= -0.0003
# ==============================
# -----------------------------------------------------
# date_val
# 1    0.00167
# 2   -0.00026
# 4   -0.00024
# Name: pls, dtype: float64
# -----------------------------------------------------
# -0.00030    3
#  0.00006    3
#  0.00028    1
#  0.00087    1
#  0.00002    1
# -0.00032    1
#  0.00005    1
#  0.00030    1
#  0.00069    1
# Name: pls, dtype: int64
# -----------------------------------------------------
# Wall time: 7min 48s
