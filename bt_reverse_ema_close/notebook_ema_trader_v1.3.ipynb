# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *
import winsound

# %%
data['pl_move_flag'] = True
data['stop_loss_flag']  = True
# data['tick_close_flag'] = True

# %%
data['sema_len']        = 50
data['lema_len']        = 500

data['angle_len']       = 200
data['tick_angle_len']  = 400

# %%
# %%time
data = get_date_list(data)
data = read_data(data)
data = run_engine(data)

if data["plot"]:
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['date_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df']['pls'].value_counts())
print('-----------------------------------------------------')
data['report_df']

winsound.PlaySound('C:\\Windows\\Media\\tada.wav', winsound.SND_ASYNC)
# Out:
#  96%|█████████████████████████████████▋ | 58437/60757 [03:13<00:08, 263.37it/s]
# pls   -0.00094
# dtype: float64
# --------------------------------------
#                   date order_type order_methods     close_type      pls
# 0  2021-04-07 00:55:33       long          make    angle_close  0.00020
# 1  2021-04-07 02:05:42      short          make  pl_move_close  0.00005
# 2  2021-04-07 02:08:24      short          make  pl_move_close  0.00005
# 3  2021-04-07 02:36:28      short          make      stop_loss -0.00021
# 4  2021-04-07 03:53:08       long          make      stop_loss -0.00020
# 5  2021-04-07 05:19:46       long          make      stop_loss -0.00020
# 6  2021-04-07 06:20:10       long          make      stop_loss -0.00021
# 7  2021-04-07 06:22:33      short          make      stop_loss -0.00020
# 8  2021-04-07 07:01:38      short          make      stop_loss -0.00023
# 9  2021-04-07 08:22:50      short          make  pl_move_close  0.00004
# 10 2021-04-07 08:58:54       long          make  pl_move_close  0.00005
# 11 2021-04-07 09:47:51      short          make      stop_loss -0.00020
# 12 2021-04-07 10:47:11      short          make      stop_loss -0.00020
# 13 2021-04-07 10:55:33      short          make      stop_loss -0.00021
# 14 2021-04-07 11:37:13       long          make    angle_close  0.00024
# 15 2021-04-07 12:37:25       long          make      stop_loss -0.00020
# 16 2021-04-07 12:51:59      short          make    angle_close  0.00020
# 17 2021-04-07 14:17:39      short          make      stop_loss -0.00020
# 18 2021-04-07 14:24:09       long          make  pl_move_close  0.00005
# 19 2021-04-07 14:59:10      short          make      stop_loss -0.00020
# 20 2021-04-07 15:18:37      short          make  pl_move_close  0.00005
# 21 2021-04-07 15:32:35      short          make    angle_close  0.00021
# 22 2021-04-07 16:29:00      short          make  pl_move_close  0.00005
# 23 2021-04-07 16:41:42       long          make  pl_move_close  0.00004
# 24 2021-04-07 17:03:30      short          make    angle_close  0.00020
# 25 2021-04-07 19:18:02       long          make  pl_move_close  0.00005
# 26 2021-04-07 20:16:51       long          make  pl_move_close  0.00004
# 100%|███████████████████████████████████| 60757/60757 [03:20<00:00, 302.40it/s]
# -----------------------------------------------------
# ==============================
# date_val          : ['20210407']
# Total PL : -0.0009400000000000008
# -------------
# net_pl            : -0.00094/0.00398
# -------------
# +ve               : num= 15    sum= +0.00152    avg= +0.0001
# -ve               : num= 12    sum= -0.00246    avg= -0.00021
# ==============================
# -----------------------------------------------------
# date_val
# 7   -0.00094
# Name: pls, dtype: float64
# -----------------------------------------------------
# -0.00020    8
#  0.00005    7
#  0.00020    3
# -0.00021    3
#  0.00004    3
# -0.00023    1
#  0.00021    1
#  0.00024    1
# Name: pls, dtype: int64
# -----------------------------------------------------
# Wall time: 3min 28s
