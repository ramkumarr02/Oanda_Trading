# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *

# %%
data['sema_len']  = 3000
data['close_angle'] = 45

# %%
data = get_date_list(data)
data = read_data(data)
data = run_engine(data)

if data["plot"]:
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['date_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df']['pls'].value_counts())
print('-----------------------------------------------------')
data['report_df']
# Out:
#  99%|▉| 341007/345059 [52:32<00:44, 91.3
# pls    0.0046
# dtype: float64
# --------------------------------------
#                   date  close_type     pls
# 0  2021-01-05 15:42:44  sema_close -0.0003
# 1  2021-01-06 01:19:01  sema_close  0.0019
# 2  2021-01-06 04:23:54  sema_close -0.0010
# 3  2021-01-06 12:49:43  sema_close  0.0028
# 4  2021-01-06 13:23:52  sema_close -0.0012
# 5  2021-01-06 13:43:55  sema_close -0.0007
# 6  2021-01-06 17:14:50  sema_close  0.0035
# 7  2021-01-07 02:22:48  sema_close  0.0020
# 8  2021-01-07 12:46:52  sema_close  0.0048
# 9  2021-01-07 14:43:38  sema_close -0.0008
# 10 2021-01-07 15:50:07  sema_close -0.0001
# 11 2021-01-07 15:55:07  sema_close -0.0008
# 12 2021-01-07 16:08:03  sema_close -0.0012
# 13 2021-01-07 17:29:37  sema_close -0.0014
# 14 2021-01-07 18:15:45  sema_close -0.0013
# 15 2021-01-07 21:01:50  sema_close -0.0006
# 16 2021-01-07 21:18:07  sema_close -0.0010
# 100%|█| 345059/345059 [53:10<00:00, 108.
# -----------------------------------------------------
# ==============================
# date_val          : ['20210105', '20210106', '20210107']
# Total PL : 0.004600000000000002
# -------------
# net_pl            : 0.0046/0.0254
# -------------
# +ve               : num= 5    sum= +0.015    avg= +0.003
# -ve               : num= 12    sum= -0.0104    avg= -0.00087
# ==============================
# -----------------------------------------------------
# date_val
# 5   -0.0003
# 6    0.0053
# 7   -0.0004
# Name: pls, dtype: float64
# -----------------------------------------------------
# -0.0008    2
# -0.0010    2
# -0.0012    2
# -0.0007    1
# -0.0013    1
# -0.0014    1
# -0.0003    1
#  0.0019    1
#  0.0048    1
# -0.0006    1
#  0.0035    1
# -0.0001    1
#  0.0020    1
#  0.0028    1
# Name: pls, dtype: int64
# -----------------------------------------------------
#                   date  year_val  month_val  date_val  hour_val  minute_val  \
# 0  2021-01-05 15:42:44      2021          1         5        15          42
# 1  2021-01-06 01:19:01      2021          1         6         1          19
# 2  2021-01-06 04:23:54      2021          1         6         4          23
# 3  2021-01-06 12:49:43      2021          1         6        12          49
# 4  2021-01-06 13:23:52      2021          1         6        13          23
# 5  2021-01-06 13:43:55      2021          1         6        13          43
# 6  2021-01-06 17:14:50      2021          1         6        17          14
# 7  2021-01-07 02:22:48      2021          1         7         2          22
# 8  2021-01-07 12:46:52      2021          1         7        12          46
# 9  2021-01-07 14:43:38      2021          1         7        14          43
# 10 2021-01-07 15:50:07      2021          1         7        15          50
# 11 2021-01-07 15:55:07      2021          1         7        15          55
# 12 2021-01-07 16:08:03      2021          1         7        16           8
# 13 2021-01-07 17:29:37      2021          1         7        17          29
# 14 2021-01-07 18:15:45      2021          1         7        18          15
# 15 2021-01-07 21:01:50      2021          1         7        21           1
# 16 2021-01-07 21:18:07      2021          1         7        21          18
#
#     close_type     pls
# 0   sema_close -0.0003
# 1   sema_close  0.0019
# 2   sema_close -0.0010
# 3   sema_close  0.0028
# 4   sema_close -0.0012
# 5   sema_close -0.0007
# 6   sema_close  0.0035
# 7   sema_close  0.0020
# 8   sema_close  0.0048
# 9   sema_close -0.0008
# 10  sema_close -0.0001
# 11  sema_close -0.0008
# 12  sema_close -0.0012
# 13  sema_close -0.0014
# 14  sema_close -0.0013
# 15  sema_close -0.0006
# 16  sema_close -0.0010
