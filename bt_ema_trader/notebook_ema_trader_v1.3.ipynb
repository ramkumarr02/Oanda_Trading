# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *

# %%
# %%time
data = get_date_list(data)
data = read_data(data)
data = run_engine(data)

if data["plot"]:
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['date_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df']['pls'].value_counts())
print('-----------------------------------------------------')
data['report_df']
# Out:
# pls   -0.0018
# dtype: float64
# --------------------------------------
#                   date   close_type     pls
# 0  2021-05-06 14:46:29   sema_close -0.0005
# 1  2021-05-06 15:01:09   sema_close -0.0006
# 2  2021-05-06 18:09:56   sema_close -0.0001
# 3  2021-05-07 05:51:08   sema_close  0.0004
# 4  2021-05-07 07:14:20   sema_close -0.0012
# 5  2021-05-07 07:17:26  angle_close  0.0002
# 6  2021-05-07 09:57:11   sema_close -0.0005
# 7  2021-05-07 09:58:08   sema_close -0.0002
# 8  2021-05-07 09:58:34   sema_close -0.0001
# 9  2021-05-07 09:58:47   sema_close -0.0000
# 10 2021-05-07 09:58:56   sema_close -0.0001
# 11 2021-05-07 10:49:12   sema_close -0.0002
# 12 2021-05-07 12:30:16   sema_close -0.0024
# 13 2021-05-07 12:35:14  angle_close  0.0019
# 14 2021-05-07 13:12:08  angle_close  0.0004
# 15 2021-05-07 14:51:34  angle_close  0.0022
# 16 2021-05-07 17:05:48   sema_close -0.0010
# 100%|█| 131489/131489 [19:31<00:00, 112.29it/s]
# -----------------------------------------------------
# ==============================
# date_val          : ['20210506', '20210507']
# Total PL : -0.001799999999999999
# -------------
# net_pl            : -0.0018/0.012
# -------------
# +ve               : num= 5    sum= +0.0051    avg= +0.00102
# -ve               : num= 11    sum= -0.0069    avg= -0.00063
# ==============================
# -----------------------------------------------------
# date_val
# 6   -0.0012
# 7   -0.0006
# Name: pls, dtype: float64
# -----------------------------------------------------
# -0.0001    3
# -0.0002    2
# -0.0005    2
#  0.0004    2
# -0.0006    1
# -0.0012    1
#  0.0002    1
# -0.0024    1
#  0.0022    1
#  0.0019    1
# -0.0010    1
# -0.0000    1
# Name: pls, dtype: int64
# -----------------------------------------------------
# Wall time: 19min 43s
#                   date  year_val  month_val  date_val  hour_val  minute_val  \
# 0  2021-05-06 14:46:29      2021          5         6        14          46
# 1  2021-05-06 15:01:09      2021          5         6        15           1
# 2  2021-05-06 18:09:56      2021          5         6        18           9
# 3  2021-05-07 05:51:08      2021          5         7         5          51
# 4  2021-05-07 07:14:20      2021          5         7         7          14
# 5  2021-05-07 07:17:26      2021          5         7         7          17
# 6  2021-05-07 09:57:11      2021          5         7         9          57
# 7  2021-05-07 09:58:08      2021          5         7         9          58
# 8  2021-05-07 09:58:34      2021          5         7         9          58
# 9  2021-05-07 09:58:47      2021          5         7         9          58
# 10 2021-05-07 09:58:56      2021          5         7         9          58
# 11 2021-05-07 10:49:12      2021          5         7        10          49
# 12 2021-05-07 12:30:16      2021          5         7        12          30
# 13 2021-05-07 12:35:14      2021          5         7        12          35
# 14 2021-05-07 13:12:08      2021          5         7        13          12
# 15 2021-05-07 14:51:34      2021          5         7        14          51
# 16 2021-05-07 17:05:48      2021          5         7        17           5
#
#      close_type     pls
# 0    sema_close -0.0005
# 1    sema_close -0.0006
# 2    sema_close -0.0001
# 3    sema_close  0.0004
# 4    sema_close -0.0012
# 5   angle_close  0.0002
# 6    sema_close -0.0005
# 7    sema_close -0.0002
# 8    sema_close -0.0001
# 9    sema_close -0.0000
# 10   sema_close -0.0001
# 11   sema_close -0.0002
# 12   sema_close -0.0024
# 13  angle_close  0.0019
# 14  angle_close  0.0004
# 15  angle_close  0.0022
# 16   sema_close -0.0010
