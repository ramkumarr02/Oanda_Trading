# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *

# %%
data = get_date_list(data)
data = read_data(data)
data = run_engine(data)

if data["plot"]:
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['date_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df']['pls'].value_counts())
print('-----------------------------------------------------')
data['report_df']
# Out:
# pls   -0.01
# dtype: float64
# --------------------------------------
#                   date  close_type     pls
# 0  2021-03-30 14:38:29  sema_close -0.0003
# 1  2021-03-30 14:41:01  sema_close -0.0002
# 2  2021-03-30 14:52:23  sema_close -0.0002
# 3  2021-03-30 14:52:30  sema_close -0.0001
# 4  2021-03-30 14:52:34  sema_close -0.0002
# ..                 ...         ...     ...
# 58 2021-03-31 17:06:30  sema_close -0.0003
# 59 2021-03-31 17:10:36  sema_close -0.0002
# 60 2021-03-31 17:15:22  sema_close -0.0002
# 61 2021-03-31 17:15:31  sema_close -0.0002
# 62 2021-03-31 17:16:01  sema_close -0.0001
#
# [63 rows x 3 columns]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 115052/115052 [12:22<00:00, 154.92it/s]
# -----------------------------------------------------
# ==============================
# date_val          : ['20210330', '20210331']
# Total PL : -0.010000000000000002
# -------------
# net_pl            : -0.01/0.0158
# -------------
# +ve               : num= 6    sum= +0.0029    avg= +0.00048
# -ve               : num= 57    sum= -0.0129    avg= -0.00023
# ==============================
# -----------------------------------------------------
# date_val
# 30   -0.0004
# 31   -0.0096
# Name: pls, dtype: float64
# -----------------------------------------------------
# -0.0002    31
# -0.0003    19
# -0.0001     6
#  0.0007     3
#  0.0003     2
#  0.0002     1
# -0.0004     1
# Name: pls, dtype: int64
# -----------------------------------------------------
#                   date  year_val  month_val  date_val  hour_val  minute_val  \
# 0  2021-03-30 14:38:29      2021          3        30        14          38
# 1  2021-03-30 14:41:01      2021          3        30        14          41
# 2  2021-03-30 14:52:23      2021          3        30        14          52
# 3  2021-03-30 14:52:30      2021          3        30        14          52
# 4  2021-03-30 14:52:34      2021          3        30        14          52
# ..                 ...       ...        ...       ...       ...         ...
# 58 2021-03-31 17:06:30      2021          3        31        17           6
# 59 2021-03-31 17:10:36      2021          3        31        17          10
# 60 2021-03-31 17:15:22      2021          3        31        17          15
# 61 2021-03-31 17:15:31      2021          3        31        17          15
# 62 2021-03-31 17:16:01      2021          3        31        17          16
#
#     close_type     pls
# 0   sema_close -0.0003
# 1   sema_close -0.0002
# 2   sema_close -0.0002
# 3   sema_close -0.0001
# 4   sema_close -0.0002
# ..         ...     ...
# 58  sema_close -0.0003
# 59  sema_close -0.0002
# 60  sema_close -0.0002
# 61  sema_close -0.0002
# 62  sema_close -0.0001
#
# [63 rows x 8 columns]

# %%
data['df']
# Out:
#                     DateTime      Bid      Ask  Volume  i      tick      sema  \
# 0      20210330 12:39:52.278  0.76091  0.76101       2  0  0.760960  0.760895
# 1      20210330 12:39:53.401  0.76091  0.76100       2  0  0.760955  0.760899
# 2      20210330 12:39:53.503  0.76090  0.76099       1  0  0.760945  0.760901
# 3      20210330 12:40:03.436  0.76090  0.76099       1  0  0.760945  0.760904
# 4      20210330 12:40:05.243  0.76090  0.76099       1  0  0.760945  0.760907
# ...                      ...      ...      ...     ... ..       ...       ...
# 84447  20210331 23:59:36.249  0.75938  0.75948       1  0  0.759430  0.759412
# 84448  20210331 23:59:36.351  0.75938  0.75948       1  0  0.759430  0.759413
# 84449  20210331 23:59:46.689  0.75934  0.75946       1  0  0.759400  0.759412
# 84450  20210331 23:59:46.790  0.75935  0.75945       1  0  0.759400  0.759412
# 84451  20210331 23:59:49.514  0.75935  0.75945       1  0  0.759400  0.759411
#
#            lema  sema_angle  lema_angle
# 0      0.762657   -6.025639   -8.842112
# 1      0.762657   -5.744709   -8.841024
# 2      0.762657   -5.462772   -8.839651
# 3      0.762657   -5.178908   -8.837991
# 4      0.762656   -4.894091   -8.837910
# ...         ...         ...         ...
# 84447  0.760871    4.012968   -7.128059
# 84448  0.760871    3.955467   -7.127004
# 84449  0.760870    3.896515   -7.126653
# 84450  0.760870    3.837063   -7.126064
# 84451  0.760870    3.776163   -7.125237
#
# [84452 rows x 10 columns]
