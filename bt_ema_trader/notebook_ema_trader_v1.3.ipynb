# %% [markdown]
# # ML Trader

# %%
from utils.packages import *
from utils.variables import *
from utils.i_o import *
from utils.dir_slope import *
from utils.engine import *
from utils.loops import *
from utils.order import *

# %%
data['pl_move_flag'] = True
data['tick_close_flag'] = True

# %%
# %%time
data = get_date_list(data)
data = read_data(data)
data = run_engine(data)

if data["plot"]:
    plot_graph(data)
    
print('-----------------------------------------------------')
print_report(data)
print('-----------------------------------------------------')
print(data['report_df'].groupby(['date_val'])['pls'].sum())
print('-----------------------------------------------------')
print(data['report_df']['pls'].value_counts())
print('-----------------------------------------------------')
data['report_df']
# Out:
# 100%|███████▉| 111798/112309 [08:25<00:02, 176.21it/s]
# pls   -0.00298
# dtype: float64
# --------------------------------------
#                   date     close_type      pls
# 0  2021-05-03 12:01:17  pl_move_close  0.00006
# 1  2021-05-03 12:34:45     tick_close -0.00043
# 2  2021-05-03 12:50:20  pl_move_close  0.00006
# 3  2021-05-03 13:33:31     tick_close -0.00020
# 4  2021-05-03 17:09:25    angle_close  0.00066
# 5  2021-05-03 19:05:54     tick_close -0.00038
# 6  2021-05-04 11:00:42     tick_close -0.00038
# 7  2021-05-04 13:38:42     tick_close -0.00015
# 8  2021-05-04 13:58:42  pl_move_close  0.00005
# 9  2021-05-04 14:58:05  pl_move_close  0.00005
# 10 2021-05-04 15:16:19  pl_move_close  0.00005
# 11 2021-05-04 15:48:00     tick_close -0.00050
# 12 2021-05-04 16:14:19  pl_move_close  0.00006
# 13 2021-05-04 16:42:20     tick_close -0.00035
# 14 2021-05-04 16:59:41     tick_close -0.00040
# 15 2021-05-04 17:46:07     tick_close -0.00069
# 16 2021-05-04 19:58:33  pl_move_close  0.00006
# 17 2021-05-04 20:50:10     tick_close -0.00028
# 18 2021-05-04 22:49:10     tick_close -0.00027
# 100%|████████| 112309/112309 [08:28<00:00, 220.89it/s]
# -----------------------------------------------------
# ==============================
# date_val          : ['20210501', '20210502', '20210503', '20210504']
# Total PL : -0.0029799999999999996
# -------------
# net_pl            : -0.00298/0.00508
# -------------
# +ve               : num= 8    sum= +0.00105    avg= +0.00013
# -ve               : num= 11    sum= -0.00403    avg= -0.00037
# ==============================
# -----------------------------------------------------
# date_val
# 3   -0.00023
# 4   -0.00275
# Name: pls, dtype: float64
# -----------------------------------------------------
#  0.00006    4
#  0.00005    3
# -0.00038    2
# -0.00028    1
# -0.00020    1
# -0.00043    1
# -0.00015    1
# -0.00040    1
# -0.00027    1
# -0.00050    1
# -0.00069    1
#  0.00066    1
# -0.00035    1
# Name: pls, dtype: int64
# -----------------------------------------------------
# Wall time: 8min 35s
#                   date  year_val  month_val  date_val  hour_val  minute_val  \
# 0  2021-05-03 12:01:17      2021          5         3        12           1
# 1  2021-05-03 12:34:45      2021          5         3        12          34
# 2  2021-05-03 12:50:20      2021          5         3        12          50
# 3  2021-05-03 13:33:31      2021          5         3        13          33
# 4  2021-05-03 17:09:25      2021          5         3        17           9
# 5  2021-05-03 19:05:54      2021          5         3        19           5
# 6  2021-05-04 11:00:42      2021          5         4        11           0
# 7  2021-05-04 13:38:42      2021          5         4        13          38
# 8  2021-05-04 13:58:42      2021          5         4        13          58
# 9  2021-05-04 14:58:05      2021          5         4        14          58
# 10 2021-05-04 15:16:19      2021          5         4        15          16
# 11 2021-05-04 15:48:00      2021          5         4        15          48
# 12 2021-05-04 16:14:19      2021          5         4        16          14
# 13 2021-05-04 16:42:20      2021          5         4        16          42
# 14 2021-05-04 16:59:41      2021          5         4        16          59
# 15 2021-05-04 17:46:07      2021          5         4        17          46
# 16 2021-05-04 19:58:33      2021          5         4        19          58
# 17 2021-05-04 20:50:10      2021          5         4        20          50
# 18 2021-05-04 22:49:10      2021          5         4        22          49
#
#        close_type      pls
# 0   pl_move_close  0.00006
# 1      tick_close -0.00043
# 2   pl_move_close  0.00006
# 3      tick_close -0.00020
# 4     angle_close  0.00066
# 5      tick_close -0.00038
# 6      tick_close -0.00038
# 7      tick_close -0.00015
# 8   pl_move_close  0.00005
# 9   pl_move_close  0.00005
# 10  pl_move_close  0.00005
# 11     tick_close -0.00050
# 12  pl_move_close  0.00006
# 13     tick_close -0.00035
# 14     tick_close -0.00040
# 15     tick_close -0.00069
# 16  pl_move_close  0.00006
# 17     tick_close -0.00028
# 18     tick_close -0.00027
